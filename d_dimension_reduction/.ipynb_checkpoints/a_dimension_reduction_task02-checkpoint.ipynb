# %%
import pandas as pd

c_df = pd.read_csv('./datasets/brain_cancer.csv', low_memory=False)
c_df
# Out:
#      samples                   type  1007_s_at   1053_at     117_at    121_at  \
# 0        834             ependymoma  12.498150  7.604868   6.880934  9.027128
# 1        835             ependymoma  13.067436  7.998090   7.209076  9.723322
# 2        836             ependymoma  13.068179  8.573674   8.647684  9.613002
# 3        837             ependymoma  12.456040  9.098977   6.628784  8.517677
# 4        838             ependymoma  12.699958  8.800721  11.556188  9.166309
# ..       ...                    ...        ...       ...        ...       ...
# 125      959  pilocytic_astrocytoma  12.658228  8.843270   7.672655  9.125912
# 126      960  pilocytic_astrocytoma  12.812823  8.510550   8.729699  9.104402
# 127      961  pilocytic_astrocytoma  12.706991  8.795721   7.772359  8.327273
# 128      962  pilocytic_astrocytoma  12.684593  8.293938   7.228186  8.494428
# 129      963  pilocytic_astrocytoma  12.397722  8.843524   8.825100  8.551541
#
#      1255_g_at   1294_at   1316_at   1320_at  ...  AFFX-r2-Ec-bioD-3_at  \
# 0     4.176175  7.224920  6.085942  6.835999  ...              9.979005
# 1     4.826126  7.539381  6.250962  8.012549  ...             11.924749
# 2     4.396581  7.813101  6.007746  7.178156  ...             12.154405
# 3     4.154847  8.361843  6.596064  6.347285  ...             11.969072
# 4     4.165891  7.923826  6.212754  6.866387  ...             11.411701
# ..         ...       ...       ...       ...  ...                   ...
# 125   5.495477  8.603892  7.747514  5.828978  ...             13.170441
# 126   3.967228  7.719089  7.092496  6.504812  ...             13.040267
# 127   6.329383  8.550471  6.613332  6.308945  ...             12.825383
# 128   6.049414  8.214729  7.287758  5.732710  ...             13.116581
# 129   5.002072  8.547894  6.920827  5.738159  ...             13.117180
#
#      AFFX-r2-Ec-bioD-5_at  AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  \
# 0                9.926470            12.719785            12.777792
# 1               11.215930            13.605662            13.401342
# 2               11.532460            13.764593            13.477800
# 3               11.288801            13.600828            13.379029
# 4               11.169317            13.751442            13.803646
# ..                    ...                  ...                  ...
# 125             12.676080            14.124837            13.996436
# 126             12.403316            13.978009            13.812916
# 127             12.439265            14.328373            14.008693
# 128             12.657967            14.390346            14.194904
# 129             12.699932            14.286779            14.088950
#
#      AFFX-ThrX-3_at  AFFX-ThrX-5_at  AFFX-ThrX-M_at  AFFX-TrpnX-3_at  \
# 0          5.403657        4.870548        4.047380         3.721936
# 1          5.224555        4.895315        3.786437         3.564481
# 2          5.303565        5.052184        4.005343         3.595382
# 3          4.953429        4.708371        3.892318         3.759429
# 4          4.892677        4.773806        3.796856         3.577544
# ..              ...             ...             ...              ...
# 125        4.913579        4.399176        3.878855         3.680103
# 126        5.189600        4.912618        3.764800         3.664920
# 127        4.931460        4.712895        3.913637         3.700964
# 128        4.871092        4.739400        3.782980         3.920363
# 129        4.932377        4.700205        3.952850         3.678112
#
#      AFFX-TrpnX-5_at  AFFX-TrpnX-M_at
# 0           4.516434         4.749940
# 1           4.430891         4.491416
# 2           4.563494         4.668827
# 3           4.748381         4.521275
# 4           4.504385         4.541450
# ..               ...              ...
# 125         4.726784         4.564637
# 126         4.628355         4.761351
# 127         4.764693         4.834952
# 128         4.665584         4.613326
# 129         5.018501         4.704779
#
# [130 rows x 54677 columns]

# %%
c_df.type.value_counts()
# Out:
# type
# ependymoma               46
# glioblastoma             34
# medulloblastoma          22
# pilocytic_astrocytoma    15
# normal                   13
# Name: count, dtype: int64

# %%
c_df.isna().sum().sum()
# Out:
# 0

# %%
c_df.samples.value_counts()
# Out:
# samples
# 834    1
# 931    1
# 929    1
# 928    1
# 927    1
#       ..
# 872    1
# 871    1
# 870    1
# 869    1
# 963    1
# Name: count, Length: 130, dtype: int64

# %%
c_df = c_df.drop(labels=['samples'], axis=1)
c_df
# Out:
#                       type  1007_s_at   1053_at     117_at    121_at  \
# 0               ependymoma  12.498150  7.604868   6.880934  9.027128
# 1               ependymoma  13.067436  7.998090   7.209076  9.723322
# 2               ependymoma  13.068179  8.573674   8.647684  9.613002
# 3               ependymoma  12.456040  9.098977   6.628784  8.517677
# 4               ependymoma  12.699958  8.800721  11.556188  9.166309
# ..                     ...        ...       ...        ...       ...
# 125  pilocytic_astrocytoma  12.658228  8.843270   7.672655  9.125912
# 126  pilocytic_astrocytoma  12.812823  8.510550   8.729699  9.104402
# 127  pilocytic_astrocytoma  12.706991  8.795721   7.772359  8.327273
# 128  pilocytic_astrocytoma  12.684593  8.293938   7.228186  8.494428
# 129  pilocytic_astrocytoma  12.397722  8.843524   8.825100  8.551541
#
#      1255_g_at   1294_at   1316_at   1320_at  1405_i_at  ...  \
# 0     4.176175  7.224920  6.085942  6.835999   5.898355  ...
# 1     4.826126  7.539381  6.250962  8.012549   5.453147  ...
# 2     4.396581  7.813101  6.007746  7.178156   8.400266  ...
# 3     4.154847  8.361843  6.596064  6.347285   4.900380  ...
# 4     4.165891  7.923826  6.212754  6.866387   5.405628  ...
# ..         ...       ...       ...       ...        ...  ...
# 125   5.495477  8.603892  7.747514  5.828978   6.926720  ...
# 126   3.967228  7.719089  7.092496  6.504812   6.157163  ...
# 127   6.329383  8.550471  6.613332  6.308945   7.494852  ...
# 128   6.049414  8.214729  7.287758  5.732710   6.296021  ...
# 129   5.002072  8.547894  6.920827  5.738159   6.383309  ...
#
#      AFFX-r2-Ec-bioD-3_at  AFFX-r2-Ec-bioD-5_at  AFFX-r2-P1-cre-3_at  \
# 0                9.979005              9.926470            12.719785
# 1               11.924749             11.215930            13.605662
# 2               12.154405             11.532460            13.764593
# 3               11.969072             11.288801            13.600828
# 4               11.411701             11.169317            13.751442
# ..                    ...                   ...                  ...
# 125             13.170441             12.676080            14.124837
# 126             13.040267             12.403316            13.978009
# 127             12.825383             12.439265            14.328373
# 128             13.116581             12.657967            14.390346
# 129             13.117180             12.699932            14.286779
#
#      AFFX-r2-P1-cre-5_at  AFFX-ThrX-3_at  AFFX-ThrX-5_at  AFFX-ThrX-M_at  \
# 0              12.777792        5.403657        4.870548        4.047380
# 1              13.401342        5.224555        4.895315        3.786437
# 2              13.477800        5.303565        5.052184        4.005343
# 3              13.379029        4.953429        4.708371        3.892318
# 4              13.803646        4.892677        4.773806        3.796856
# ..                   ...             ...             ...             ...
# 125            13.996436        4.913579        4.399176        3.878855
# 126            13.812916        5.189600        4.912618        3.764800
# 127            14.008693        4.931460        4.712895        3.913637
# 128            14.194904        4.871092        4.739400        3.782980
# 129            14.088950        4.932377        4.700205        3.952850
#
#      AFFX-TrpnX-3_at  AFFX-TrpnX-5_at  AFFX-TrpnX-M_at
# 0           3.721936         4.516434         4.749940
# 1           3.564481         4.430891         4.491416
# 2           3.595382         4.563494         4.668827
# 3           3.759429         4.748381         4.521275
# 4           3.577544         4.504385         4.541450
# ..               ...              ...              ...
# 125         3.680103         4.726784         4.564637
# 126         3.664920         4.628355         4.761351
# 127         3.700964         4.764693         4.834952
# 128         3.920363         4.665584         4.613326
# 129         3.678112         5.018501         4.704779
#
# [130 rows x 54676 columns]

# %%
from sklearn.preprocessing import StandardScaler

std = StandardScaler()
result = std.fit_transform(c_df.iloc[:, 1:])
std_c_df = pd.DataFrame(result, columns=c_df.iloc[:, 1:].columns)
std_c_df
# Out:
#      1007_s_at   1053_at    117_at    121_at  1255_g_at   1294_at   1316_at  \
# 0     0.281734 -1.736304 -0.814542 -0.217100  -0.725018 -1.184185 -1.333998
# 1     1.004990 -1.150107 -0.496988  0.918622  -0.017358 -0.683315 -1.025756
# 2     1.005934 -0.292052  0.895202  0.738654  -0.485043 -0.247338 -1.480059
# 3     0.228235  0.491046 -1.058556 -1.048181  -0.748240  0.626689 -0.381139
# 4     0.538123  0.046420  3.709860  0.009951  -0.736216 -0.070977 -1.097124
# ..         ...       ...       ...       ...        ...       ...       ...
# 125   0.485107  0.109849 -0.048366 -0.055950   0.711424  1.012222  1.769656
# 126   0.681513 -0.386154  0.974571 -0.091039  -0.952518 -0.397080  0.546147
# 127   0.547059  0.038965  0.048121 -1.358793   1.619374  0.927133 -0.348885
# 128   0.518602 -0.709070 -0.478494 -1.086108   1.314546  0.392369  0.910877
# 129   0.154144  0.110228  1.066894 -0.992938   0.174210  0.923029  0.225486
#
#       1320_at  1405_i_at   1431_at  ...  AFFX-r2-Ec-bioD-3_at  \
# 0    0.553088  -0.189429 -0.055937  ...             -3.937805
# 1    2.343052  -0.683739  0.999013  ...             -0.734738
# 2    1.073633   2.588411  1.239468  ...             -0.356680
# 3   -0.190425  -1.297469  0.736078  ...             -0.661774
# 4    0.599319  -0.736499 -0.429866  ...             -1.579314
# ..        ...        ...       ...  ...                   ...
# 125 -0.978959   0.952351 -0.929134  ...              1.315909
# 126  0.049232   0.097921 -0.744390  ...              1.101618
# 127 -0.248754   1.583142 -1.005822  ...              0.747877
# 128 -1.125418   0.252094 -0.652057  ...              1.227245
# 129 -1.117129   0.349009 -0.510417  ...              1.228231
#
#      AFFX-r2-Ec-bioD-5_at  AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  \
# 0               -3.063362            -3.368328            -2.732332
# 1               -0.969428            -0.590331            -0.707073
# 2               -0.455420            -0.091946            -0.458744
# 3               -0.851095            -0.605492            -0.779546
# 4               -1.045122            -0.133185             0.599587
# ..                    ...                  ...                  ...
# 125              1.401686             1.037736             1.225759
# 126              0.958748             0.577300             0.629695
# 127              1.017127             1.675996             1.265570
# 128              1.372272             1.870338             1.870372
# 129              1.440419             1.545565             1.526239
#
#      AFFX-ThrX-3_at  AFFX-ThrX-5_at  AFFX-ThrX-M_at  AFFX-TrpnX-3_at  \
# 0          0.897836        0.268867        0.790096         0.113594
# 1          0.083428        0.381955       -0.788721        -0.763316
# 2          0.442703        1.098238        0.535753        -0.591219
# 3         -1.149432       -0.471656       -0.148096         0.322405
# 4         -1.425683       -0.172871       -0.725682        -0.690563
# ..              ...             ...             ...              ...
# 125       -1.330637       -1.883481       -0.229553        -0.119385
# 126       -0.075517        0.460963       -0.919634        -0.203942
# 127       -1.249327       -0.451001       -0.019103        -0.003202
# 128       -1.523832       -0.329972       -0.809633         1.218691
# 129       -1.245157       -0.508942        0.218150        -0.130474
#
#      AFFX-TrpnX-5_at  AFFX-TrpnX-M_at
# 0          -0.696548         0.608331
# 1          -1.231041        -0.740878
# 2          -0.402498         0.185009
# 3           0.752725        -0.585045
# 4          -0.771828        -0.479759
# ..               ...              ...
# 125         0.617781        -0.358746
# 126         0.002770         0.667883
# 127         0.854646         1.051999
# 128         0.235385        -0.104642
# 129         2.440505         0.372638
#
# [130 rows x 54675 columns]

# %%
# for column in std_c_df.columns:
#     std_c_df = std_c_df[std_c_df[column].between(-1.96, 1.96)]

# std_c_df

# %%
from sklearn.preprocessing import LabelEncoder

type_encoder = LabelEncoder()
result = type_encoder.fit_transform(c_df['type'])
std_c_df['target'] = result
std_c_df
# Out:
#      1007_s_at   1053_at    117_at    121_at  1255_g_at   1294_at   1316_at  \
# 0     0.281734 -1.736304 -0.814542 -0.217100  -0.725018 -1.184185 -1.333998
# 1     1.004990 -1.150107 -0.496988  0.918622  -0.017358 -0.683315 -1.025756
# 2     1.005934 -0.292052  0.895202  0.738654  -0.485043 -0.247338 -1.480059
# 3     0.228235  0.491046 -1.058556 -1.048181  -0.748240  0.626689 -0.381139
# 4     0.538123  0.046420  3.709860  0.009951  -0.736216 -0.070977 -1.097124
# ..         ...       ...       ...       ...        ...       ...       ...
# 125   0.485107  0.109849 -0.048366 -0.055950   0.711424  1.012222  1.769656
# 126   0.681513 -0.386154  0.974571 -0.091039  -0.952518 -0.397080  0.546147
# 127   0.547059  0.038965  0.048121 -1.358793   1.619374  0.927133 -0.348885
# 128   0.518602 -0.709070 -0.478494 -1.086108   1.314546  0.392369  0.910877
# 129   0.154144  0.110228  1.066894 -0.992938   0.174210  0.923029  0.225486
#
#       1320_at  1405_i_at   1431_at  ...  AFFX-r2-Ec-bioD-5_at  \
# 0    0.553088  -0.189429 -0.055937  ...             -3.063362
# 1    2.343052  -0.683739  0.999013  ...             -0.969428
# 2    1.073633   2.588411  1.239468  ...             -0.455420
# 3   -0.190425  -1.297469  0.736078  ...             -0.851095
# 4    0.599319  -0.736499 -0.429866  ...             -1.045122
# ..        ...        ...       ...  ...                   ...
# 125 -0.978959   0.952351 -0.929134  ...              1.401686
# 126  0.049232   0.097921 -0.744390  ...              0.958748
# 127 -0.248754   1.583142 -1.005822  ...              1.017127
# 128 -1.125418   0.252094 -0.652057  ...              1.372272
# 129 -1.117129   0.349009 -0.510417  ...              1.440419
#
#      AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  AFFX-ThrX-3_at  AFFX-ThrX-5_at  \
# 0              -3.368328            -2.732332        0.897836        0.268867
# 1              -0.590331            -0.707073        0.083428        0.381955
# 2              -0.091946            -0.458744        0.442703        1.098238
# 3              -0.605492            -0.779546       -1.149432       -0.471656
# 4              -0.133185             0.599587       -1.425683       -0.172871
# ..                   ...                  ...             ...             ...
# 125             1.037736             1.225759       -1.330637       -1.883481
# 126             0.577300             0.629695       -0.075517        0.460963
# 127             1.675996             1.265570       -1.249327       -0.451001
# 128             1.870338             1.870372       -1.523832       -0.329972
# 129             1.545565             1.526239       -1.245157       -0.508942
#
#      AFFX-ThrX-M_at  AFFX-TrpnX-3_at  AFFX-TrpnX-5_at  AFFX-TrpnX-M_at  target
# 0          0.790096         0.113594        -0.696548         0.608331       0
# 1         -0.788721        -0.763316        -1.231041        -0.740878       0
# 2          0.535753        -0.591219        -0.402498         0.185009       0
# 3         -0.148096         0.322405         0.752725        -0.585045       0
# 4         -0.725682        -0.690563        -0.771828        -0.479759       0
# ..              ...              ...              ...              ...     ...
# 125       -0.229553        -0.119385         0.617781        -0.358746       4
# 126       -0.919634        -0.203942         0.002770         0.667883       4
# 127       -0.019103        -0.003202         0.854646         1.051999       4
# 128       -0.809633         1.218691         0.235385        -0.104642       4
# 129        0.218150        -0.130474         2.440505         0.372638       4
#
# [130 rows x 54676 columns]

# %%
from sklearn.model_selection import train_test_split

features, targets = std_c_df.iloc[:, :-1], std_c_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

# %%
train_df = pd.concat([X_train, y_train], axis=1).reset_index(drop=True)
test_df = pd.concat([X_test, y_test], axis=1).reset_index(drop=True)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=9)

pca_train = pca.fit_transform(train_df.iloc[:, :-1])
pca_test = pca.fit_transform(test_df.iloc[:, :-1])

print(pca_train.shape, pca_test.shape)
# Out:
# (104, 9) (26, 9)

# %%
pca_columns = [f'pca{i + 1}' for i in range(pca_train.shape[1])]
pca_train_df = pd.DataFrame(pca_train, columns=pca_columns)
pca_train_df.loc[:, 'target'] = train_df['target']

# %%
pca_columns = [f'pca{i + 1}' for i in range(pca_test.shape[1])]
pca_test_df = pd.DataFrame(pca_test, columns=pca_columns)
pca_test_df.loc[:, 'target'] = test_df['target']

# %%
# print(pca.explained_variance_ratio_)
print(pca.explained_variance_ratio_.sum())
# Out:
# 0.7379071301853046

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

features, targets = pca_train_df.iloc[:, :-1], pca_train_df.iloc[:, -1]
parameters = {'max_depth': [5, 10, 20], 'min_samples_split': [10, 50, 100]}

rfc = RandomForestClassifier()

g_rfc = GridSearchCV(rfc, param_grid=parameters, cv=5, return_train_score=True, scoring='accuracy')
g_rfc.fit(features, targets)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [5, 10, 20],
#                          'min_samples_split': [10, 50, 100]},
#              return_train_score=True, scoring='accuracy')

# %%
result_df = pd.DataFrame(g_rfc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                         params  mean_test_score  \
# 0    {'max_depth': 5, 'min_samples_split': 10}         0.904286
# 1    {'max_depth': 5, 'min_samples_split': 50}         0.615238
# 2   {'max_depth': 5, 'min_samples_split': 100}         0.355714
# 3   {'max_depth': 10, 'min_samples_split': 10}         0.894762
# 4   {'max_depth': 10, 'min_samples_split': 50}         0.643810
# 5  {'max_depth': 10, 'min_samples_split': 100}         0.355714
# 6   {'max_depth': 20, 'min_samples_split': 10}         0.883810
# 7   {'max_depth': 20, 'min_samples_split': 50}         0.577143
# 8  {'max_depth': 20, 'min_samples_split': 100}         0.355714
#
#    rank_test_score
# 0                1
# 1                5
# 2                7
# 3                2
# 4                4
# 5                7
# 6                3
# 7                6
# 8                7

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

def get_evaluation(y_test, prediction, classifier=None, X_test=None):
    confusion = confusion_matrix(y_test, prediction)
    accuracy = accuracy_score(y_test , prediction)
    precision = precision_score(y_test , prediction)
    recall = recall_score(y_test , prediction)
    f1 = f1_score(y_test, prediction)
    auc = roc_auc_score(y_test, prediction)
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, ROC-AUC: {4:.4f}'.format(accuracy, precision, recall, f1, auc))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
X_test, y_test = pca_test_df.iloc[:, :-1], pca_test_df.iloc[:, -1]

rfc = g_rfc.best_estimator_
prediction = rfc.predict(X_test)
get_evaluation(y_test, prediction, rfc, X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 5
#       3 rfc = g_rfc.best_estimator_
#       4 prediction = rfc.predict(X_test)
# ----> 5 get_evaluation(y_test, prediction, rfc, X_test)
#
# Cell In[67], line 7, in get_evaluation(y_test, prediction, classifier, X_test)
#       5 confusion = confusion_matrix(y_test, prediction)
#       6 accuracy = accuracy_score(y_test , prediction)
# ----> 7 precision = precision_score(y_test , prediction)
#       8 recall = recall_score(y_test , prediction)
#       9 f1 = f1_score(y_test, prediction)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1954, in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1825 def precision_score(
#    1826     y_true,
#    1827     y_pred,
#    (...)
#    1833     zero_division="warn",
#    1834 ):
#    1835     """Compute the precision.
#    1836
#    1837     The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1952     array([0.5, 1. , 1. ])
#    1953     """
# -> 1954     p, _, _, _ = precision_recall_fscore_support(
#    1955         y_true,
#    1956         y_pred,
#    1957         labels=labels,
#    1958         pos_label=pos_label,
#    1959         average=average,
#    1960         warn_for=("precision",),
#    1961         sample_weight=sample_weight,
#    1962         zero_division=zero_division,
#    1963     )
#    1964     return p
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1573, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1571 if beta < 0:
#    1572     raise ValueError("beta should be >=0 in the F-beta score")
# -> 1573 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1575 # Calculate tp_sum, pred_sum, true_sum ###
#    1576 samplewise = average == "samples"
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1391, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1389         if y_type == "multiclass":
#    1390             average_options.remove("samples")
# -> 1391         raise ValueError(
#    1392             "Target is %s but average='binary'. Please "
#    1393             "choose another average setting, one of %r." % (y_type, average_options)
#    1394         )
#    1395 elif pos_label not in (None, 1):
#    1396     warnings.warn(
#    1397         "Note that pos_label (set to %r) is ignored when "
#    1398         "average != 'binary' (got %r). You may use "
#    (...)
#    1401         UserWarning,
#    1402     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
