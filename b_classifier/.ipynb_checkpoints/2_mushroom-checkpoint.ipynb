# %% [markdown]
# ### 버섯의 특징에 따른 독버섯 분류모델
# > https://www.kaggle.com/datasets/vishalpnaik/mushroom-classification-edible-or-poisonous

# %% [markdown]
# 1. class - 독버섯과 일반버섯 구분(p - poison, e - edible)(target)
# 2. cap-diameter - 버섯 캡 지름
# 3. cap-shape - 버섯 캡 모양
# 4. cap-surface - 버섯 캡 표면(질감 등)
# 5. cap-color - 버섯 캡 색상
# 6. does-bruise-or-bleed - 버섯 특징(상처입거나 압력을 받을 때 색깔이 변하거나 출혈하는 여부)
# 7. gill-attachment - 버섯 잔가락
# 8. gill-spacing - 잔가락 간격
# 9. gill-color - 잔가락 색상
# 10. stem-height - 줄기 높이
# 11. stem-width - 줄기 너비
# 12. stem-root - 줄기 뿌리
# 13. stem-surface - 줄기 표면
# 14. stem-color - 줄기 색상
# 15. veil-type - 베일 유형(버섯 캡 아래 얇고 막힌 층)
# 16. veil-color - 베일 색상
# 17. has-ring - 버섯 줄기 주변 고리
# 18. ring-type - 고리 유형
# 19. spore-print-color - 포자가 표면에 떨어져 남긴 색상
# 20. habitat - 버섯의 서식지
# 21. season - 버섯의 출현 시기

# %%
import pandas as pd
mr_df_origin = pd.read_csv('./datasets/mushroom.csv')
mr_df = mr_df_origin.copy()
mr_df
# Out:
#       class  cap-diameter cap-shape cap-surface cap-color  \
# 0         p         15.26         x           g         o
# 1         p         16.60         x           g         o
# 2         p         14.07         x           g         o
# 3         p         14.17         f           h         e
# 4         p         14.64         x           h         o
# ...     ...           ...       ...         ...       ...
# 61064     p          1.18         s           s         y
# 61065     p          1.27         f           s         y
# 61066     p          1.27         s           s         y
# 61067     p          1.24         f           s         y
# 61068     p          1.17         s           s         y
#
#       does-bruise-or-bleed gill-attachment gill-spacing gill-color  \
# 0                        f               e          NaN          w
# 1                        f               e          NaN          w
# 2                        f               e          NaN          w
# 3                        f               e          NaN          w
# 4                        f               e          NaN          w
# ...                    ...             ...          ...        ...
# 61064                    f               f            f          f
# 61065                    f               f            f          f
# 61066                    f               f            f          f
# 61067                    f               f            f          f
# 61068                    f               f            f          f
#
#        stem-height  ...  stem-root stem-surface stem-color veil-type  \
# 0            16.95  ...          s            y          w         u
# 1            17.99  ...          s            y          w         u
# 2            17.80  ...          s            y          w         u
# 3            15.77  ...          s            y          w         u
# 4            16.53  ...          s            y          w         u
# ...            ...  ...        ...          ...        ...       ...
# 61064         3.93  ...        NaN          NaN          y       NaN
# 61065         3.18  ...        NaN          NaN          y       NaN
# 61066         3.86  ...        NaN          NaN          y       NaN
# 61067         3.56  ...        NaN          NaN          y       NaN
# 61068         3.25  ...        NaN          NaN          y       NaN
#
#       veil-color has-ring ring-type spore-print-color habitat season
# 0              w        t         g               NaN       d      w
# 1              w        t         g               NaN       d      u
# 2              w        t         g               NaN       d      w
# 3              w        t         p               NaN       d      w
# 4              w        t         p               NaN       d      w
# ...          ...      ...       ...               ...     ...    ...
# 61064        NaN        f         f               NaN       d      a
# 61065        NaN        f         f               NaN       d      a
# 61066        NaN        f         f               NaN       d      u
# 61067        NaN        f         f               NaN       d      u
# 61068        NaN        f         f               NaN       d      u
#
# [61069 rows x 21 columns]

# %%
mr_df.duplicated().sum()
# Out:
# 146

# %%
mr_df = mr_df.drop_duplicates()

# %%
mr_df.duplicated().sum()
# Out:
# 0

# %%
mr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60923 entries, 0 to 61068
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   class                 60923 non-null  object
#  1   cap-diameter          60923 non-null  float64
#  2   cap-shape             60923 non-null  object
#  3   cap-surface           46803 non-null  object
#  4   cap-color             60923 non-null  object
#  5   does-bruise-or-bleed  60923 non-null  object
#  6   gill-attachment       51068 non-null  object
#  7   gill-spacing          35861 non-null  object
#  8   gill-color            60923 non-null  object
#  9   stem-height           60923 non-null  float64
#  10  stem-width            60923 non-null  float64
#  11  stem-root             9387 non-null   object
#  12  stem-surface          22801 non-null  object
#  13  stem-color            60923 non-null  object
#  14  veil-type             3177 non-null   object
#  15  veil-color            7413 non-null   object
#  16  has-ring              60923 non-null  object
#  17  ring-type             58452 non-null  object
#  18  spore-print-color     6326 non-null   object
#  19  habitat               60923 non-null  object
#  20  season                60923 non-null  object
# dtypes: float64(3), object(18)
# memory usage: 10.2+ MB

# %%
mr_df.isna().sum()
# Out:
# class                       0
# cap-diameter                0
# cap-shape                   0
# cap-surface             14120
# cap-color                   0
# does-bruise-or-bleed        0
# gill-attachment          9855
# gill-spacing            25062
# gill-color                  0
# stem-height                 0
# stem-width                  0
# stem-root               51536
# stem-surface            38122
# stem-color                  0
# veil-type               57746
# veil-color              53510
# has-ring                    0
# ring-type                2471
# spore-print-color       54597
# habitat                     0
# season                      0
# dtype: int64

# %%
# 버섯 캡 표면(질감)
mr_df['cap-surface'].value_counts()
# Out:
# cap-surface
# t    8184
# s    7580
# y    6341
# h    4974
# g    4722
# d    4432
# e    2584
# k    2303
# i    2225
# w    2150
# l    1308
# Name: count, dtype: int64

# %%
# 버섯 잔가락 유형
mr_df['gill-attachment'].value_counts()
# Out:
# gill-attachment
# a    12697
# d    10247
# x     7413
# p     6001
# e     5648
# s     5648
# f     3414
# Name: count, dtype: int64

# %%
# 고리 타입
mr_df['ring-type'].value_counts()
# Out:
# ring-type
# f    48215
# e     2435
# z     2118
# l     1427
# r     1399
# p     1265
# g     1240
# m      353
# Name: count, dtype: int64

# %%
# 고리 타입은 결측치가 조금밖에 없지만 대체할 순 없다고 판단하여 결측치 제거
mr_df = mr_df[~ mr_df['ring-type'].isna()]
mr_df.isna().sum()
# Out:
# class                       0
# cap-diameter                0
# cap-shape                   0
# cap-surface             13767
# cap-color                   0
# does-bruise-or-bleed        0
# gill-attachment          9502
# gill-spacing            24003
# gill-color                  0
# stem-height                 0
# stem-width                  0
# stem-root               49418
# stem-surface            36710
# stem-color                  0
# veil-type               55275
# veil-color              51745
# has-ring                    0
# ring-type                   0
# spore-print-color       52832
# habitat                     0
# season                      0
# dtype: int64

# %%
# 크게 중요하지않고 대체하기 힘들 것 같다 판단하여 드랍
mr_df = mr_df.drop(labels=[
                             'cap-surface', 
                             'gill-attachment',
                             'gill-spacing',
                             'stem-root', 
                             'stem-surface', 
                             'veil-type', 
                             'veil-color', 
                             'spore-print-color'], axis=1)

# %%
mr_df
# Out:
#       class  cap-diameter cap-shape cap-color does-bruise-or-bleed gill-color  \
# 0         p         15.26         x         o                    f          w
# 1         p         16.60         x         o                    f          w
# 2         p         14.07         x         o                    f          w
# 3         p         14.17         f         e                    f          w
# 4         p         14.64         x         o                    f          w
# ...     ...           ...       ...       ...                  ...        ...
# 61064     p          1.18         s         y                    f          f
# 61065     p          1.27         f         y                    f          f
# 61066     p          1.27         s         y                    f          f
# 61067     p          1.24         f         y                    f          f
# 61068     p          1.17         s         y                    f          f
#
#        stem-height  stem-width stem-color has-ring ring-type habitat season
# 0            16.95       17.09          w        t         g       d      w
# 1            17.99       18.19          w        t         g       d      u
# 2            17.80       17.74          w        t         g       d      w
# 3            15.77       15.98          w        t         p       d      w
# 4            16.53       17.20          w        t         p       d      w
# ...            ...         ...        ...      ...       ...     ...    ...
# 61064         3.93        6.22          y        f         f       d      a
# 61065         3.18        5.43          y        f         f       d      a
# 61066         3.86        6.37          y        f         f       d      u
# 61067         3.56        5.44          y        f         f       d      u
# 61068         3.25        5.45          y        f         f       d      u
#
# [58452 rows x 13 columns]

# %%
mr_df.hist()
# Out:
# array([[<Axes: title={'center': 'cap-diameter'}>,
#         <Axes: title={'center': 'stem-height'}>],
#        [<Axes: title={'center': 'stem-width'}>, <Axes: >]], dtype=object)

# %%
# 타겟 컬럼을 맨 뒤로 보냄
mr_df['target'] = mr_df['class']
mr_df
# Out:
#       class  cap-diameter cap-shape cap-color does-bruise-or-bleed gill-color  \
# 0         p         15.26         x         o                    f          w
# 1         p         16.60         x         o                    f          w
# 2         p         14.07         x         o                    f          w
# 3         p         14.17         f         e                    f          w
# 4         p         14.64         x         o                    f          w
# ...     ...           ...       ...       ...                  ...        ...
# 61064     p          1.18         s         y                    f          f
# 61065     p          1.27         f         y                    f          f
# 61066     p          1.27         s         y                    f          f
# 61067     p          1.24         f         y                    f          f
# 61068     p          1.17         s         y                    f          f
#
#        stem-height  stem-width stem-color has-ring ring-type habitat season  \
# 0            16.95       17.09          w        t         g       d      w
# 1            17.99       18.19          w        t         g       d      u
# 2            17.80       17.74          w        t         g       d      w
# 3            15.77       15.98          w        t         p       d      w
# 4            16.53       17.20          w        t         p       d      w
# ...            ...         ...        ...      ...       ...     ...    ...
# 61064         3.93        6.22          y        f         f       d      a
# 61065         3.18        5.43          y        f         f       d      a
# 61066         3.86        6.37          y        f         f       d      u
# 61067         3.56        5.44          y        f         f       d      u
# 61068         3.25        5.45          y        f         f       d      u
#
#       target
# 0          p
# 1          p
# 2          p
# 3          p
# 4          p
# ...      ...
# 61064      p
# 61065      p
# 61066      p
# 61067      p
# 61068      p
#
# [58452 rows x 14 columns]

# %%
mr_df = mr_df.drop(labels=['class'], axis=1)
mr_df
# Out:
#        cap-diameter cap-shape cap-color does-bruise-or-bleed gill-color  \
# 0             15.26         x         o                    f          w
# 1             16.60         x         o                    f          w
# 2             14.07         x         o                    f          w
# 3             14.17         f         e                    f          w
# 4             14.64         x         o                    f          w
# ...             ...       ...       ...                  ...        ...
# 61064          1.18         s         y                    f          f
# 61065          1.27         f         y                    f          f
# 61066          1.27         s         y                    f          f
# 61067          1.24         f         y                    f          f
# 61068          1.17         s         y                    f          f
#
#        stem-height  stem-width stem-color has-ring ring-type habitat season  \
# 0            16.95       17.09          w        t         g       d      w
# 1            17.99       18.19          w        t         g       d      u
# 2            17.80       17.74          w        t         g       d      w
# 3            15.77       15.98          w        t         p       d      w
# 4            16.53       17.20          w        t         p       d      w
# ...            ...         ...        ...      ...       ...     ...    ...
# 61064         3.93        6.22          y        f         f       d      a
# 61065         3.18        5.43          y        f         f       d      a
# 61066         3.86        6.37          y        f         f       d      u
# 61067         3.56        5.44          y        f         f       d      u
# 61068         3.25        5.45          y        f         f       d      u
#
#       target
# 0          p
# 1          p
# 2          p
# 3          p
# 4          p
# ...      ...
# 61064      p
# 61065      p
# 61066      p
# 61067      p
# 61068      p
#
# [58452 rows x 13 columns]

# %%
# StandardScaler로 변환한 값 중 -1.96 ~ 1.96을 벗어난 범위의 값 확인
import numpy as np
from sklearn.preprocessing import StandardScaler

std = StandardScaler()

features = ['cap-diameter', 'stem-height', 'stem-width']

total_count = mr_df.shape[0]
for feature in features:
    std_df = std.fit_transform(mr_df[[feature]])
    count = ((std_df < -1.96) | (std_df > 1.96)).sum()
    print(f'{feature}: {count}건, {np.round(count / total_count * 100, 4)}%')
# Out:
# cap-diameter: 1893건, 3.2386%
# stem-height: 2566건, 4.3899%
# stem-width: 2348건, 4.017%

# %%
# 이상치도 많지않아 제거
sbp_df = mr_df.loc[:, 'cap-diameter'].reset_index()
std_sbp_df = std.fit_transform(sbp_df[['cap-diameter']])
sbp_df['cap-diameter'] = std_sbp_df
sbp_df = sbp_df[sbp_df['cap-diameter'].between(-1.96, 1.96)]
mr_df = mr_df.iloc[sbp_df.index].reset_index(drop=True)

dbp_df = mr_df.loc[:, 'stem-height'].reset_index()
std_dbp_df = std.fit_transform(dbp_df[['stem-height']])
dbp_df['stem-height'] = std_dbp_df
dbp_df = dbp_df[dbp_df['stem-height'].between(-1.96, 1.96)]
mr_df = mr_df.iloc[dbp_df.index].reset_index(drop=True)

blds_df = mr_df.loc[:, 'stem-width'].reset_index()
std_blds_df = std.fit_transform(blds_df[['stem-width']])
blds_df['stem-width'] = std_blds_df
blds_df = blds_df[blds_df['stem-width'].between(-1.96, 1.96)]
mr_df = mr_df.iloc[blds_df.index].reset_index(drop=True)

mr_df
# Out:
#        cap-diameter cap-shape cap-color does-bruise-or-bleed gill-color  \
# 0              6.87         x         n                    f          w
# 1              8.59         p         n                    f          w
# 2              5.95         p         n                    f          w
# 3              6.51         x         n                    f          w
# 4              7.66         x         n                    f          w
# ...             ...       ...       ...                  ...        ...
# 50912          1.18         s         y                    f          f
# 50913          1.27         f         y                    f          f
# 50914          1.27         s         y                    f          f
# 50915          1.24         f         y                    f          f
# 50916          1.17         s         y                    f          f
#
#        stem-height  stem-width stem-color has-ring ring-type habitat season  \
# 0             6.88       13.64          w        t         p       d      a
# 1             9.15       17.34          w        t         p       d      a
# 2             7.54       12.73          w        t         p       d      u
# 3             6.80       12.92          w        t         p       d      a
# 4             8.55       14.98          w        t         p       d      a
# ...            ...         ...        ...      ...       ...     ...    ...
# 50912         3.93        6.22          y        f         f       d      a
# 50913         3.18        5.43          y        f         f       d      a
# 50914         3.86        6.37          y        f         f       d      u
# 50915         3.56        5.44          y        f         f       d      u
# 50916         3.25        5.45          y        f         f       d      u
#
#       target
# 0          p
# 1          p
# 2          p
# 3          p
# 4          p
# ...      ...
# 50912      p
# 50913      p
# 50914      p
# 50915      p
# 50916      p
#
# [50917 rows x 13 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# 인코딩
columns = ['cap-shape', 'cap-color', 'does-bruise-or-bleed', 'gill-color', 'stem-color', 'has-ring', 'ring-type', 'habitat', 'season', 'target']
encoders = {}

for column in columns:
    encoder = LabelEncoder()
    mr_df[column] = encoder.fit_transform(mr_df[column])
    encoders[column] = encoder.classes_.tolist()

# %%
mr_df
# Out:
#        cap-diameter  cap-shape  cap-color  does-bruise-or-bleed  gill-color  \
# 0              6.87          6          5                     0          10
# 1              8.59          4          5                     0          10
# 2              5.95          4          5                     0          10
# 3              6.51          6          5                     0          10
# 4              7.66          6          5                     0          10
# ...             ...        ...        ...                   ...         ...
# 50912          1.18          5         11                     0           2
# 50913          1.27          2         11                     0           2
# 50914          1.27          5         11                     0           2
# 50915          1.24          2         11                     0           2
# 50916          1.17          5         11                     0           2
#
#        stem-height  stem-width  stem-color  has-ring  ring-type  habitat  \
# 0             6.88       13.64          10         1          4        0
# 1             9.15       17.34          10         1          4        0
# 2             7.54       12.73          10         1          4        0
# 3             6.80       12.92          10         1          4        0
# 4             8.55       14.98          10         1          4        0
# ...            ...         ...         ...       ...        ...      ...
# 50912         3.93        6.22          11         0          1        0
# 50913         3.18        5.43          11         0          1        0
# 50914         3.86        6.37          11         0          1        0
# 50915         3.56        5.44          11         0          1        0
# 50916         3.25        5.45          11         0          1        0
#
#        season  target
# 0           0       1
# 1           0       1
# 2           2       1
# 3           0       1
# 4           0       1
# ...       ...     ...
# 50912       0       1
# 50913       0       1
# 50914       2       1
# 50915       2       1
# 50916       2       1
#
# [50917 rows x 13 columns]

# %%
# 0 - 식용, 1 - 독성
encoders['target']
# Out:
# ['e', 'p']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(5, 4))
corr = mr_df.corr()
heatmap = sns.heatmap(corr, cmap='Purples')
heatmap.set_title('Correlation')
plt.show()

# %%
corr = mr_df.corr()
corr[['target']].sort_values(by='target', ascending=False)[1:]
# Out:
#                         target
# ring-type             0.095623
# has-ring              0.090753
# cap-color             0.063815
# habitat              -0.009529
# does-bruise-or-bleed -0.024577
# gill-color           -0.028574
# season               -0.058860
# stem-height          -0.073438
# stem-color           -0.087070
# cap-shape            -0.089115
# cap-diameter         -0.201708
# stem-width           -0.231248

# %% [markdown]
# - 타겟피처와 상관관계가 모두 낮다

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

def get_evaluation(y_test, prediction, classifier=None, X_test=None):
    confusion = confusion_matrix(y_test, prediction)
    accuracy = accuracy_score(y_test , prediction)
    precision = precision_score(y_test , prediction)
    recall = recall_score(y_test , prediction)
    f1 = f1_score(y_test, prediction)
    auc = roc_auc_score(y_test, prediction)
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, ROC-AUC: {4:.4f}'.format(accuracy, precision, recall, f1, auc))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %% [markdown]
# ### dtc

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

features, targets = mr_df.iloc[:, :-1], mr_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

# target피쳐의 불균형을 업샘플링
smote = SMOTE(random_state=124)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)

y_train_over.value_counts()
# Out:
# target
# 1    22508
# 0    22508
# Name: count, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

dtc = DecisionTreeClassifier()

dtc.fit(X_train_over, y_train_over)
# Out:
# DecisionTreeClassifier()

# %%
# from sklearn.tree import export_graphviz

# export_graphviz(
#     dtc, 
#     out_file='./images/mushroom01.dot', 
#     class_names=encoders['target'], 
#     feature_names=features.columns, 
#     impurity=True, 
#     filled=True
# )

# %%
# import graphviz

# with open('./images/mushroom01.dot') as f:
#     mushroom_dtc01 = f.read()

# mushroom_dtc01_graph = graphviz.Source(mushroom_dtc01)

# %%
# mushroom_dtc01_graph.render(filename='mushroom01', directory='./images', format='png')

# %% [markdown]
# <img src="./images/mushroom01.png">

# %% [markdown]
# #### dtc 오차행렬

# %%
prediction = dtc.predict(X_test)
get_evaluation(y_test, prediction, dtc, X_test)
# Out:
# 오차 행렬
# [[4488   68]
#  [  62 5566]]
# 정확도: 0.9872, 정밀도: 0.9879, 재현율: 0.9890, F1: 0.9885, ROC-AUC: 0.9870
# ################################################################################

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.tree import DecisionTreeClassifier
dtc_parameters = {'max_depth': [24, 25, 26], 'min_samples_split': [50, 51, 52]}

dtc = DecisionTreeClassifier()

g_dtc = GridSearchCV(dtc, param_grid=dtc_parameters, cv=3, refit=True, return_train_score=True, n_jobs=-1)

# %%
g_dtc.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [24, 25, 26],
#                          'min_samples_split': [50, 51, 52]},
#              return_train_score=True)

# %%
dtc_result_df = pd.DataFrame(g_dtc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(dtc_result_df)

dtc = g_dtc.best_estimator_
# Out:
#                                        params  mean_test_score  \
# 0  {'max_depth': 24, 'min_samples_split': 50}         0.969922
# 1  {'max_depth': 24, 'min_samples_split': 51}         0.969500
# 2  {'max_depth': 24, 'min_samples_split': 52}         0.968833
# 3  {'max_depth': 25, 'min_samples_split': 50}         0.969766
# 4  {'max_depth': 25, 'min_samples_split': 51}         0.969477
# 5  {'max_depth': 25, 'min_samples_split': 52}         0.968789
# 6  {'max_depth': 26, 'min_samples_split': 50}         0.969677
# 7  {'max_depth': 26, 'min_samples_split': 51}         0.969522
# 8  {'max_depth': 26, 'min_samples_split': 52}         0.968855
#
#    rank_test_score
# 0                1
# 1                5
# 2                8
# 3                2
# 4                6
# 5                9
# 6                3
# 7                4
# 8                7

# %% [markdown]
# #### 교차검증 후 dtc

# %%
dtc_prediction = dtc.predict(X_test)
get_evaluation(y_test, dtc_prediction, dtc, X_test)
# Out:
# 오차 행렬
# [[4435  121]
#  [ 110 5518]]
# 정확도: 0.9773, 정밀도: 0.9785, 재현율: 0.9805, F1: 0.9795, ROC-AUC: 0.9769
# ################################################################################

# %% [markdown]
# ### K-Nearest Neighbor(최근접 이웃)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_parameters = {'knn__n_neighbors': [3, 5, 7, 9, 11]}

knn = KNeighborsClassifier()

knn_pipe = Pipeline([('standard_scaler', StandardScaler()), ('knn', knn)])
g_knn = GridSearchCV(knn_pipe, param_grid=knn_parameters, cv=3, refit=True, return_train_score=True, n_jobs=-1)

g_knn.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('standard_scaler', StandardScaler()),
#                                        ('knn', KNeighborsClassifier())]),
#              n_jobs=-1, param_grid={'knn__n_neighbors': [3, 5, 7, 9, 11]},
#              return_train_score=True)

# %%
knn_result_df = pd.DataFrame(g_knn.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
print(knn_result_df['params'].iloc[3])
display(knn_result_df)

knn = KNeighborsClassifier(n_neighbors=9)
knn_pipe = Pipeline([('standard_scaler', StandardScaler()), ('knn', knn)])

knn_pipe.fit(X_train_over, y_train_over)
# Out:
# {'knn__n_neighbors': 9}
#                      params  mean_test_score  rank_test_score
# 0   {'knn__n_neighbors': 3}         0.991581                1
# 1   {'knn__n_neighbors': 5}         0.988471                2
# 2   {'knn__n_neighbors': 7}         0.984206                3
# 3   {'knn__n_neighbors': 9}         0.980674                4
# 4  {'knn__n_neighbors': 11}         0.978119                5
# Pipeline(steps=[('standard_scaler', StandardScaler()),
#                 ('knn', KNeighborsClassifier(n_neighbors=9))])

# %%
knn_prediction = knn_pipe.predict(X_test)
get_evaluation(y_test, knn_prediction, knn_pipe, X_test)
# Out:
# 오차 행렬
# [[4504   52]
#  [  81 5547]]
# 정확도: 0.9869, 정밀도: 0.9907, 재현율: 0.9856, F1: 0.9882, ROC-AUC: 0.9871
# ################################################################################

# %% [markdown]
# ### svc
# > fit하는데 열시간 이상 경과해도 학습이 되지않아 다른 데이터셋으로 해보기

# %%
# from sklearn.svm import SVC
# svc_parameters = {'svc__C': [0.001, 0.01, 0.1, 1, 10, 100],
#                   'svc__gamma': [0.001, 0.01, 0.1, 1, 10, 100],
#                   'svc__kernel': ['linear', 'rbf']}

# svc = SVC(probability=True, verbose=True)

# svc_pipe = Pipeline([('standard_scaler', StandardScaler()), ('svc', svc)])
# g_svc = GridSearchCV(svc_pipe, param_grid=svc_parameters, cv=3, refit=True, return_train_score=True, n_jobs=-1)

# %%
# g_svc.fit(X_train_over, y_train_over)

# %% [markdown]
# ### 랜덤 포레스트

# %%
from sklearn.ensemble import RandomForestClassifier

rfc_parameters = {
    'max_depth': [24, 25, 26], 
    'min_samples_split': [50, 51, 52]
}

rfc = RandomForestClassifier(n_estimators=100)

g_rfc = GridSearchCV(rfc, param_grid=rfc_parameters, cv=10, n_jobs=-1)

g_rfc.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [24, 25, 26],
#                          'min_samples_split': [50, 51, 52]})

# %%
result_df = pd.DataFrame(g_rfc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                        params  mean_test_score  \
# 0  {'max_depth': 24, 'min_samples_split': 50}         0.992669
# 1  {'max_depth': 24, 'min_samples_split': 51}         0.992803
# 2  {'max_depth': 24, 'min_samples_split': 52}         0.992625
# 3  {'max_depth': 25, 'min_samples_split': 50}         0.992669
# 4  {'max_depth': 25, 'min_samples_split': 51}         0.992936
# 5  {'max_depth': 25, 'min_samples_split': 52}         0.992869
# 6  {'max_depth': 26, 'min_samples_split': 50}         0.992803
# 7  {'max_depth': 26, 'min_samples_split': 51}         0.992803
# 8  {'max_depth': 26, 'min_samples_split': 52}         0.992958
#
#    rank_test_score
# 0                8
# 1                4
# 2                9
# 3                7
# 4                2
# 5                3
# 6                5
# 7                6
# 8                1

# %%
rfc = g_rfc.best_estimator_
rfc_prediction = rfc.predict(X_test)

# %% [markdown]
# #### RandomForest 오차행렬

# %%
get_evaluation(y_test, rfc_prediction, rfc, X_test)
# Out:
# 오차 행렬
# [[4525   31]
#  [  42 5586]]
# 정확도: 0.9928, 정밀도: 0.9945, 재현율: 0.9925, F1: 0.9935, ROC-AUC: 0.9929
# ################################################################################

# %% [markdown]
# - 랜덤포레스트가 결과가 굉장히 좋다

# %% [markdown]
# ### boosting - adaboost

# %%
from sklearn.ensemble import AdaBoostClassifier

parmeters = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

adabc = AdaBoostClassifier()

g_ada = GridSearchCV(adabc, param_grid=parmeters, cv=5, n_jobs=-1)
g_ada.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.3, 0.5, 0.7, 1],
#                          'n_estimators': [50, 100, 150]})

# %%
result_df = pd.DataFrame(g_ada.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.3, 'n_estimators': 50}         0.701973
# 1   {'learning_rate': 0.3, 'n_estimators': 100}         0.725253
# 2   {'learning_rate': 0.3, 'n_estimators': 150}         0.736160
# 3    {'learning_rate': 0.5, 'n_estimators': 50}         0.723232
# 4   {'learning_rate': 0.5, 'n_estimators': 100}         0.742736
# 5   {'learning_rate': 0.5, 'n_estimators': 150}         0.749178
# 6    {'learning_rate': 0.7, 'n_estimators': 50}         0.737582
# 7   {'learning_rate': 0.7, 'n_estimators': 100}         0.751644
# 8   {'learning_rate': 0.7, 'n_estimators': 150}         0.759374
# 9      {'learning_rate': 1, 'n_estimators': 50}         0.745335
# 10    {'learning_rate': 1, 'n_estimators': 100}         0.759685
# 11    {'learning_rate': 1, 'n_estimators': 150}         0.767149
#
#     rank_test_score
# 0                12
# 1                10
# 2                 9
# 3                11
# 4                 7
# 5                 5
# 6                 8
# 7                 4
# 8                 3
# 9                 6
# 10                2
# 11                1

# %%
ada = g_ada.best_estimator_
ada_prediction = ada.predict(X_test)

# %% [markdown]
# ### ada 오차행렬

# %%
get_evaluation(y_test, ada_prediction, ada, X_test)
# Out:
# 오차 행렬
# [[3636  920]
#  [1466 4162]]
# 정확도: 0.7657, 정밀도: 0.8190, 재현율: 0.7395, F1: 0.7772, ROC-AUC: 0.7688
# ################################################################################

# %% [markdown]
# - 모든 수치가 조금씩 낮은 모습

# %% [markdown]
# ### boosting - GBM

# %%
from sklearn.ensemble import GradientBoostingClassifier

parameters = {
    'n_estimators': [50, 100, 500],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

g_gbc = GridSearchCV(GradientBoostingClassifier(loss='log_loss'), param_grid=parameters, cv=5)
g_gbc.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.3, 0.5, 0.7, 1],
#                          'n_estimators': [50, 100, 500]})

# %%
result_df = pd.DataFrame(g_gbc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.3, 'n_estimators': 50}         0.912187
# 1   {'learning_rate': 0.3, 'n_estimators': 100}         0.949329
# 2   {'learning_rate': 0.3, 'n_estimators': 500}         0.989448
# 3    {'learning_rate': 0.5, 'n_estimators': 50}         0.934934
# 4   {'learning_rate': 0.5, 'n_estimators': 100}         0.968811
# 5   {'learning_rate': 0.5, 'n_estimators': 500}         0.992314
# 6    {'learning_rate': 0.7, 'n_estimators': 50}         0.949485
# 7   {'learning_rate': 0.7, 'n_estimators': 100}         0.974565
# 8   {'learning_rate': 0.7, 'n_estimators': 500}         0.991136
# 9      {'learning_rate': 1, 'n_estimators': 50}         0.962747
# 10    {'learning_rate': 1, 'n_estimators': 100}         0.982006
# 11    {'learning_rate': 1, 'n_estimators': 500}         0.990159
#
#     rank_test_score
# 0                12
# 1                10
# 2                 4
# 3                11
# 4                 7
# 5                 1
# 6                 9
# 7                 6
# 8                 2
# 9                 8
# 10                5
# 11                3

# %%
gbc = g_gbc.best_estimator_
gbc_prediction = gbc.predict(X_test)

# %% [markdown]
# #### GBM 오차행렬

# %%
get_evaluation(y_test, gbc_prediction, gbc, X_test)
# Out:
# 오차 행렬
# [[4531   25]
#  [  31 5597]]
# 정확도: 0.9945, 정밀도: 0.9956, 재현율: 0.9945, F1: 0.9950, ROC-AUC: 0.9945
# ################################################################################

# %% [markdown]
# ### boosting - XGBoost

# %%
from xgboost import XGBClassifier

X_val_train, X_val_test, y_val_train, y_val_test = \
train_test_split(X_train, y_train, stratify=y_train, test_size=0.2, random_state=124)

evals = [(X_val_train, y_val_train), (X_val_test, y_val_test)]

# %%
from sklearn.model_selection import GridSearchCV

parameters = {
    'n_estimators': [50, 100, 500],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

xgb = XGBClassifier()

g_xgb = GridSearchCV(xgb, 
                     param_grid=parameters, 
                     cv=5, 
                     refit=True, 
                     return_train_score=True, 
                     n_jobs=-1)

g_xgb.fit(X_train_over, y_train_over, early_stopping_rounds=50, eval_set=evals)
# Out:
# [0]	validation_0-logloss:0.61238	validation_1-logloss:0.60902
# [1]	validation_0-logloss:0.54481	validation_1-logloss:0.53905
# [2]	validation_0-logloss:0.51003	validation_1-logloss:0.50341
# [3]	validation_0-logloss:0.46201	validation_1-logloss:0.45711
# [4]	validation_0-logloss:0.40652	validation_1-logloss:0.40215
# [5]	validation_0-logloss:0.37776	validation_1-logloss:0.37376
# [6]	validation_0-logloss:0.35798	validation_1-logloss:0.35516
# [7]	validation_0-logloss:0.31916	validation_1-logloss:0.31821
# [8]	validation_0-logloss:0.29384	validation_1-logloss:0.29196
# [9]	validation_0-logloss:0.27867	validation_1-logloss:0.27548
# [10]	validation_0-logloss:0.25689	validation_1-logloss:0.25476
# [11]	validation_0-logloss:0.24779	validation_1-logloss:0.24572
# [12]	validation_0-logloss:0.23830	validation_1-logloss:0.23700
# [13]	validation_0-logloss:0.22027	validation_1-logloss:0.21952
# [14]	validation_0-logloss:0.21577	validation_1-logloss:0.21481
# [15]	validation_0-logloss:0.21130	validation_1-logloss:0.21032
# [16]	validation_0-logloss:0.19523	validation_1-logloss:0.19492
# [17]	validation_0-logloss:0.18464	validation_1-logloss:0.18504
# [18]	validation_0-logloss:0.17953	validation_1-logloss:0.17919
# C:\ProgramData\anaconda3\Lib\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [19]	validation_0-logloss:0.17410	validation_1-logloss:0.17368
# [20]	validation_0-logloss:0.17234	validation_1-logloss:0.17193
# [21]	validation_0-logloss:0.16866	validation_1-logloss:0.16840
# [22]	validation_0-logloss:0.16314	validation_1-logloss:0.16289
# [23]	validation_0-logloss:0.15737	validation_1-logloss:0.15756
# [24]	validation_0-logloss:0.15469	validation_1-logloss:0.15473
# [25]	validation_0-logloss:0.15014	validation_1-logloss:0.15028
# [26]	validation_0-logloss:0.13989	validation_1-logloss:0.13975
# [27]	validation_0-logloss:0.13234	validation_1-logloss:0.13192
# [28]	validation_0-logloss:0.12515	validation_1-logloss:0.12490
# [29]	validation_0-logloss:0.11639	validation_1-logloss:0.11563
# [30]	validation_0-logloss:0.11127	validation_1-logloss:0.11075
# [31]	validation_0-logloss:0.10747	validation_1-logloss:0.10693
# [32]	validation_0-logloss:0.10293	validation_1-logloss:0.10273
# [33]	validation_0-logloss:0.09847	validation_1-logloss:0.09808
# [34]	validation_0-logloss:0.08993	validation_1-logloss:0.08973
# [35]	validation_0-logloss:0.08729	validation_1-logloss:0.08719
# [36]	validation_0-logloss:0.08372	validation_1-logloss:0.08359
# [37]	validation_0-logloss:0.07881	validation_1-logloss:0.07878
# [38]	validation_0-logloss:0.07542	validation_1-logloss:0.07522
# [39]	validation_0-logloss:0.07249	validation_1-logloss:0.07216
# [40]	validation_0-logloss:0.06962	validation_1-logloss:0.06938
# [41]	validation_0-logloss:0.06699	validation_1-logloss:0.06643
# [42]	validation_0-logloss:0.06625	validation_1-logloss:0.06556
# [43]	validation_0-logloss:0.06556	validation_1-logloss:0.06486
# [44]	validation_0-logloss:0.06515	validation_1-logloss:0.06443
# [45]	validation_0-logloss:0.05995	validation_1-logloss:0.05946
# [46]	validation_0-logloss:0.05746	validation_1-logloss:0.05704
# [47]	validation_0-logloss:0.05500	validation_1-logloss:0.05397
# [48]	validation_0-logloss:0.05289	validation_1-logloss:0.05183
# [49]	validation_0-logloss:0.05004	validation_1-logloss:0.04887
# [50]	validation_0-logloss:0.04814	validation_1-logloss:0.04692
# [51]	validation_0-logloss:0.04615	validation_1-logloss:0.04487
# [52]	validation_0-logloss:0.04529	validation_1-logloss:0.04377
# [53]	validation_0-logloss:0.04467	validation_1-logloss:0.04306
# [54]	validation_0-logloss:0.04398	validation_1-logloss:0.04244
# [55]	validation_0-logloss:0.04271	validation_1-logloss:0.04112
# [56]	validation_0-logloss:0.04152	validation_1-logloss:0.03986
# [57]	validation_0-logloss:0.03974	validation_1-logloss:0.03798
# [58]	validation_0-logloss:0.03831	validation_1-logloss:0.03669
# [59]	validation_0-logloss:0.03641	validation_1-logloss:0.03486
# [60]	validation_0-logloss:0.03517	validation_1-logloss:0.03350
# [61]	validation_0-logloss:0.03441	validation_1-logloss:0.03268
# [62]	validation_0-logloss:0.03346	validation_1-logloss:0.03170
# [63]	validation_0-logloss:0.03306	validation_1-logloss:0.03123
# [64]	validation_0-logloss:0.03273	validation_1-logloss:0.03089
# [65]	validation_0-logloss:0.03155	validation_1-logloss:0.02986
# [66]	validation_0-logloss:0.03069	validation_1-logloss:0.02894
# [67]	validation_0-logloss:0.02976	validation_1-logloss:0.02803
# [68]	validation_0-logloss:0.02890	validation_1-logloss:0.02719
# [69]	validation_0-logloss:0.02770	validation_1-logloss:0.02631
# [70]	validation_0-logloss:0.02739	validation_1-logloss:0.02601
# [71]	validation_0-logloss:0.02676	validation_1-logloss:0.02540
# [72]	validation_0-logloss:0.02589	validation_1-logloss:0.02436
# [73]	validation_0-logloss:0.02510	validation_1-logloss:0.02357
# [74]	validation_0-logloss:0.02467	validation_1-logloss:0.02315
# [75]	validation_0-logloss:0.02430	validation_1-logloss:0.02273
# [76]	validation_0-logloss:0.02396	validation_1-logloss:0.02240
# [77]	validation_0-logloss:0.02306	validation_1-logloss:0.02174
# [78]	validation_0-logloss:0.02293	validation_1-logloss:0.02160
# [79]	validation_0-logloss:0.02215	validation_1-logloss:0.02069
# [80]	validation_0-logloss:0.02179	validation_1-logloss:0.02041
# [81]	validation_0-logloss:0.02108	validation_1-logloss:0.01966
# [82]	validation_0-logloss:0.02034	validation_1-logloss:0.01895
# [83]	validation_0-logloss:0.01992	validation_1-logloss:0.01862
# [84]	validation_0-logloss:0.01923	validation_1-logloss:0.01795
# [85]	validation_0-logloss:0.01841	validation_1-logloss:0.01697
# [86]	validation_0-logloss:0.01813	validation_1-logloss:0.01670
# [87]	validation_0-logloss:0.01781	validation_1-logloss:0.01640
# [88]	validation_0-logloss:0.01729	validation_1-logloss:0.01596
# [89]	validation_0-logloss:0.01695	validation_1-logloss:0.01556
# [90]	validation_0-logloss:0.01657	validation_1-logloss:0.01515
# [91]	validation_0-logloss:0.01630	validation_1-logloss:0.01494
# [92]	validation_0-logloss:0.01607	validation_1-logloss:0.01475
# [93]	validation_0-logloss:0.01555	validation_1-logloss:0.01419
# [94]	validation_0-logloss:0.01539	validation_1-logloss:0.01404
# [95]	validation_0-logloss:0.01514	validation_1-logloss:0.01382
# [96]	validation_0-logloss:0.01461	validation_1-logloss:0.01340
# [97]	validation_0-logloss:0.01445	validation_1-logloss:0.01326
# [98]	validation_0-logloss:0.01423	validation_1-logloss:0.01300
# [99]	validation_0-logloss:0.01408	validation_1-logloss:0.01284
# [100]	validation_0-logloss:0.01370	validation_1-logloss:0.01252
# [101]	validation_0-logloss:0.01348	validation_1-logloss:0.01231
# [102]	validation_0-logloss:0.01330	validation_1-logloss:0.01217
# [103]	validation_0-logloss:0.01315	validation_1-logloss:0.01198
# [104]	validation_0-logloss:0.01279	validation_1-logloss:0.01166
# [105]	validation_0-logloss:0.01266	validation_1-logloss:0.01154
# [106]	validation_0-logloss:0.01230	validation_1-logloss:0.01116
# [107]	validation_0-logloss:0.01215	validation_1-logloss:0.01095
# [108]	validation_0-logloss:0.01207	validation_1-logloss:0.01086
# [109]	validation_0-logloss:0.01198	validation_1-logloss:0.01074
# [110]	validation_0-logloss:0.01173	validation_1-logloss:0.01048
# [111]	validation_0-logloss:0.01161	validation_1-logloss:0.01034
# [112]	validation_0-logloss:0.01145	validation_1-logloss:0.01017
# [113]	validation_0-logloss:0.01108	validation_1-logloss:0.00980
# [114]	validation_0-logloss:0.01094	validation_1-logloss:0.00966
# [115]	validation_0-logloss:0.01086	validation_1-logloss:0.00958
# [116]	validation_0-logloss:0.01060	validation_1-logloss:0.00940
# [117]	validation_0-logloss:0.01050	validation_1-logloss:0.00933
# [118]	validation_0-logloss:0.01043	validation_1-logloss:0.00922
# [119]	validation_0-logloss:0.01028	validation_1-logloss:0.00908
# [120]	validation_0-logloss:0.01010	validation_1-logloss:0.00890
# [121]	validation_0-logloss:0.00997	validation_1-logloss:0.00875
# [122]	validation_0-logloss:0.00990	validation_1-logloss:0.00868
# [123]	validation_0-logloss:0.00981	validation_1-logloss:0.00862
# [124]	validation_0-logloss:0.00960	validation_1-logloss:0.00848
# [125]	validation_0-logloss:0.00948	validation_1-logloss:0.00835
# [126]	validation_0-logloss:0.00943	validation_1-logloss:0.00827
# [127]	validation_0-logloss:0.00936	validation_1-logloss:0.00820
# [128]	validation_0-logloss:0.00924	validation_1-logloss:0.00803
# [129]	validation_0-logloss:0.00916	validation_1-logloss:0.00798
# [130]	validation_0-logloss:0.00900	validation_1-logloss:0.00789
# [131]	validation_0-logloss:0.00897	validation_1-logloss:0.00786
# [132]	validation_0-logloss:0.00877	validation_1-logloss:0.00771
# [133]	validation_0-logloss:0.00874	validation_1-logloss:0.00768
# [134]	validation_0-logloss:0.00870	validation_1-logloss:0.00767
# [135]	validation_0-logloss:0.00855	validation_1-logloss:0.00758
# [136]	validation_0-logloss:0.00848	validation_1-logloss:0.00750
# [137]	validation_0-logloss:0.00845	validation_1-logloss:0.00749
# [138]	validation_0-logloss:0.00827	validation_1-logloss:0.00733
# [139]	validation_0-logloss:0.00816	validation_1-logloss:0.00721
# [140]	validation_0-logloss:0.00805	validation_1-logloss:0.00710
# [141]	validation_0-logloss:0.00799	validation_1-logloss:0.00704
# [142]	validation_0-logloss:0.00793	validation_1-logloss:0.00699
# [143]	validation_0-logloss:0.00788	validation_1-logloss:0.00693
# [144]	validation_0-logloss:0.00783	validation_1-logloss:0.00690
# [145]	validation_0-logloss:0.00769	validation_1-logloss:0.00678
# [146]	validation_0-logloss:0.00757	validation_1-logloss:0.00665
# [147]	validation_0-logloss:0.00747	validation_1-logloss:0.00656
# [148]	validation_0-logloss:0.00736	validation_1-logloss:0.00645
# [149]	validation_0-logloss:0.00724	validation_1-logloss:0.00635
# [150]	validation_0-logloss:0.00713	validation_1-logloss:0.00624
# [151]	validation_0-logloss:0.00703	validation_1-logloss:0.00613
# [152]	validation_0-logloss:0.00694	validation_1-logloss:0.00604
# [153]	validation_0-logloss:0.00689	validation_1-logloss:0.00600
# [154]	validation_0-logloss:0.00679	validation_1-logloss:0.00589
# [155]	validation_0-logloss:0.00675	validation_1-logloss:0.00584
# [156]	validation_0-logloss:0.00674	validation_1-logloss:0.00583
# [157]	validation_0-logloss:0.00665	validation_1-logloss:0.00573
# [158]	validation_0-logloss:0.00660	validation_1-logloss:0.00571
# [159]	validation_0-logloss:0.00655	validation_1-logloss:0.00567
# [160]	validation_0-logloss:0.00649	validation_1-logloss:0.00564
# [161]	validation_0-logloss:0.00644	validation_1-logloss:0.00560
# [162]	validation_0-logloss:0.00637	validation_1-logloss:0.00555
# [163]	validation_0-logloss:0.00629	validation_1-logloss:0.00547
# [164]	validation_0-logloss:0.00625	validation_1-logloss:0.00542
# [165]	validation_0-logloss:0.00622	validation_1-logloss:0.00538
# [166]	validation_0-logloss:0.00620	validation_1-logloss:0.00537
# [167]	validation_0-logloss:0.00614	validation_1-logloss:0.00531
# [168]	validation_0-logloss:0.00612	validation_1-logloss:0.00529
# [169]	validation_0-logloss:0.00606	validation_1-logloss:0.00527
# [170]	validation_0-logloss:0.00602	validation_1-logloss:0.00524
# [171]	validation_0-logloss:0.00594	validation_1-logloss:0.00515
# [172]	validation_0-logloss:0.00592	validation_1-logloss:0.00514
# [173]	validation_0-logloss:0.00586	validation_1-logloss:0.00508
# [174]	validation_0-logloss:0.00580	validation_1-logloss:0.00501
# [175]	validation_0-logloss:0.00577	validation_1-logloss:0.00499
# [176]	validation_0-logloss:0.00569	validation_1-logloss:0.00490
# [177]	validation_0-logloss:0.00565	validation_1-logloss:0.00487
# [178]	validation_0-logloss:0.00561	validation_1-logloss:0.00482
# [179]	validation_0-logloss:0.00556	validation_1-logloss:0.00478
# [180]	validation_0-logloss:0.00546	validation_1-logloss:0.00468
# [181]	validation_0-logloss:0.00534	validation_1-logloss:0.00462
# [182]	validation_0-logloss:0.00533	validation_1-logloss:0.00460
# [183]	validation_0-logloss:0.00531	validation_1-logloss:0.00459
# [184]	validation_0-logloss:0.00529	validation_1-logloss:0.00457
# [185]	validation_0-logloss:0.00526	validation_1-logloss:0.00449
# [186]	validation_0-logloss:0.00524	validation_1-logloss:0.00449
# [187]	validation_0-logloss:0.00522	validation_1-logloss:0.00446
# [188]	validation_0-logloss:0.00518	validation_1-logloss:0.00445
# [189]	validation_0-logloss:0.00515	validation_1-logloss:0.00442
# [190]	validation_0-logloss:0.00510	validation_1-logloss:0.00436
# [191]	validation_0-logloss:0.00502	validation_1-logloss:0.00431
# [192]	validation_0-logloss:0.00497	validation_1-logloss:0.00426
# [193]	validation_0-logloss:0.00493	validation_1-logloss:0.00423
# [194]	validation_0-logloss:0.00485	validation_1-logloss:0.00418
# [195]	validation_0-logloss:0.00483	validation_1-logloss:0.00416
# [196]	validation_0-logloss:0.00482	validation_1-logloss:0.00414
# [197]	validation_0-logloss:0.00478	validation_1-logloss:0.00411
# [198]	validation_0-logloss:0.00475	validation_1-logloss:0.00407
# [199]	validation_0-logloss:0.00472	validation_1-logloss:0.00407
# [200]	validation_0-logloss:0.00470	validation_1-logloss:0.00404
# [201]	validation_0-logloss:0.00467	validation_1-logloss:0.00401
# [202]	validation_0-logloss:0.00463	validation_1-logloss:0.00398
# [203]	validation_0-logloss:0.00458	validation_1-logloss:0.00396
# [204]	validation_0-logloss:0.00456	validation_1-logloss:0.00393
# [205]	validation_0-logloss:0.00453	validation_1-logloss:0.00391
# [206]	validation_0-logloss:0.00449	validation_1-logloss:0.00387
# [207]	validation_0-logloss:0.00446	validation_1-logloss:0.00386
# [208]	validation_0-logloss:0.00443	validation_1-logloss:0.00383
# [209]	validation_0-logloss:0.00438	validation_1-logloss:0.00382
# [210]	validation_0-logloss:0.00436	validation_1-logloss:0.00379
# [211]	validation_0-logloss:0.00432	validation_1-logloss:0.00376
# [212]	validation_0-logloss:0.00427	validation_1-logloss:0.00370
# [213]	validation_0-logloss:0.00422	validation_1-logloss:0.00364
# [214]	validation_0-logloss:0.00419	validation_1-logloss:0.00361
# [215]	validation_0-logloss:0.00416	validation_1-logloss:0.00359
# [216]	validation_0-logloss:0.00413	validation_1-logloss:0.00357
# [217]	validation_0-logloss:0.00410	validation_1-logloss:0.00355
# [218]	validation_0-logloss:0.00407	validation_1-logloss:0.00352
# [219]	validation_0-logloss:0.00405	validation_1-logloss:0.00350
# [220]	validation_0-logloss:0.00403	validation_1-logloss:0.00349
# [221]	validation_0-logloss:0.00401	validation_1-logloss:0.00347
# [222]	validation_0-logloss:0.00399	validation_1-logloss:0.00348
# [223]	validation_0-logloss:0.00396	validation_1-logloss:0.00345
# [224]	validation_0-logloss:0.00395	validation_1-logloss:0.00344
# [225]	validation_0-logloss:0.00394	validation_1-logloss:0.00343
# [226]	validation_0-logloss:0.00390	validation_1-logloss:0.00340
# [227]	validation_0-logloss:0.00389	validation_1-logloss:0.00338
# [228]	validation_0-logloss:0.00385	validation_1-logloss:0.00336
# [229]	validation_0-logloss:0.00382	validation_1-logloss:0.00333
# [230]	validation_0-logloss:0.00379	validation_1-logloss:0.00331
# [231]	validation_0-logloss:0.00378	validation_1-logloss:0.00329
# [232]	validation_0-logloss:0.00372	validation_1-logloss:0.00323
# [233]	validation_0-logloss:0.00369	validation_1-logloss:0.00320
# [234]	validation_0-logloss:0.00366	validation_1-logloss:0.00319
# [235]	validation_0-logloss:0.00362	validation_1-logloss:0.00317
# [236]	validation_0-logloss:0.00361	validation_1-logloss:0.00316
# [237]	validation_0-logloss:0.00357	validation_1-logloss:0.00312
# [238]	validation_0-logloss:0.00355	validation_1-logloss:0.00309
# [239]	validation_0-logloss:0.00354	validation_1-logloss:0.00307
# [240]	validation_0-logloss:0.00353	validation_1-logloss:0.00306
# [241]	validation_0-logloss:0.00352	validation_1-logloss:0.00305
# [242]	validation_0-logloss:0.00350	validation_1-logloss:0.00304
# [243]	validation_0-logloss:0.00348	validation_1-logloss:0.00303
# [244]	validation_0-logloss:0.00348	validation_1-logloss:0.00303
# [245]	validation_0-logloss:0.00347	validation_1-logloss:0.00303
# [246]	validation_0-logloss:0.00343	validation_1-logloss:0.00301
# [247]	validation_0-logloss:0.00340	validation_1-logloss:0.00298
# [248]	validation_0-logloss:0.00337	validation_1-logloss:0.00296
# [249]	validation_0-logloss:0.00335	validation_1-logloss:0.00294
# [250]	validation_0-logloss:0.00334	validation_1-logloss:0.00292
# [251]	validation_0-logloss:0.00332	validation_1-logloss:0.00289
# [252]	validation_0-logloss:0.00330	validation_1-logloss:0.00288
# [253]	validation_0-logloss:0.00327	validation_1-logloss:0.00285
# [254]	validation_0-logloss:0.00325	validation_1-logloss:0.00284
# [255]	validation_0-logloss:0.00324	validation_1-logloss:0.00282
# [256]	validation_0-logloss:0.00323	validation_1-logloss:0.00281
# [257]	validation_0-logloss:0.00320	validation_1-logloss:0.00280
# [258]	validation_0-logloss:0.00316	validation_1-logloss:0.00276
# [259]	validation_0-logloss:0.00313	validation_1-logloss:0.00273
# [260]	validation_0-logloss:0.00312	validation_1-logloss:0.00272
# [261]	validation_0-logloss:0.00310	validation_1-logloss:0.00271
# [262]	validation_0-logloss:0.00309	validation_1-logloss:0.00270
# [263]	validation_0-logloss:0.00308	validation_1-logloss:0.00269
# [264]	validation_0-logloss:0.00304	validation_1-logloss:0.00266
# [265]	validation_0-logloss:0.00301	validation_1-logloss:0.00263
# [266]	validation_0-logloss:0.00298	validation_1-logloss:0.00261
# [267]	validation_0-logloss:0.00298	validation_1-logloss:0.00261
# [268]	validation_0-logloss:0.00297	validation_1-logloss:0.00260
# [269]	validation_0-logloss:0.00297	validation_1-logloss:0.00259
# [270]	validation_0-logloss:0.00295	validation_1-logloss:0.00259
# [271]	validation_0-logloss:0.00294	validation_1-logloss:0.00259
# [272]	validation_0-logloss:0.00292	validation_1-logloss:0.00258
# [273]	validation_0-logloss:0.00289	validation_1-logloss:0.00255
# [274]	validation_0-logloss:0.00288	validation_1-logloss:0.00254
# [275]	validation_0-logloss:0.00287	validation_1-logloss:0.00254
# [276]	validation_0-logloss:0.00285	validation_1-logloss:0.00252
# [277]	validation_0-logloss:0.00285	validation_1-logloss:0.00252
# [278]	validation_0-logloss:0.00285	validation_1-logloss:0.00252
# [279]	validation_0-logloss:0.00282	validation_1-logloss:0.00250
# [280]	validation_0-logloss:0.00280	validation_1-logloss:0.00248
# [281]	validation_0-logloss:0.00277	validation_1-logloss:0.00246
# [282]	validation_0-logloss:0.00276	validation_1-logloss:0.00244
# [283]	validation_0-logloss:0.00275	validation_1-logloss:0.00244
# [284]	validation_0-logloss:0.00274	validation_1-logloss:0.00243
# [285]	validation_0-logloss:0.00273	validation_1-logloss:0.00241
# [286]	validation_0-logloss:0.00273	validation_1-logloss:0.00240
# [287]	validation_0-logloss:0.00271	validation_1-logloss:0.00239
# [288]	validation_0-logloss:0.00269	validation_1-logloss:0.00239
# [289]	validation_0-logloss:0.00267	validation_1-logloss:0.00237
# [290]	validation_0-logloss:0.00266	validation_1-logloss:0.00236
# [291]	validation_0-logloss:0.00265	validation_1-logloss:0.00235
# [292]	validation_0-logloss:0.00264	validation_1-logloss:0.00234
# [293]	validation_0-logloss:0.00263	validation_1-logloss:0.00233
# [294]	validation_0-logloss:0.00262	validation_1-logloss:0.00233
# [295]	validation_0-logloss:0.00261	validation_1-logloss:0.00233
# [296]	validation_0-logloss:0.00261	validation_1-logloss:0.00232
# [297]	validation_0-logloss:0.00260	validation_1-logloss:0.00232
# [298]	validation_0-logloss:0.00259	validation_1-logloss:0.00231
# [299]	validation_0-logloss:0.00258	validation_1-logloss:0.00230
# [300]	validation_0-logloss:0.00256	validation_1-logloss:0.00229
# [301]	validation_0-logloss:0.00255	validation_1-logloss:0.00228
# [302]	validation_0-logloss:0.00254	validation_1-logloss:0.00228
# [303]	validation_0-logloss:0.00253	validation_1-logloss:0.00227
# [304]	validation_0-logloss:0.00253	validation_1-logloss:0.00226
# [305]	validation_0-logloss:0.00252	validation_1-logloss:0.00226
# [306]	validation_0-logloss:0.00251	validation_1-logloss:0.00225
# [307]	validation_0-logloss:0.00251	validation_1-logloss:0.00225
# [308]	validation_0-logloss:0.00251	validation_1-logloss:0.00225
# [309]	validation_0-logloss:0.00250	validation_1-logloss:0.00225
# [310]	validation_0-logloss:0.00249	validation_1-logloss:0.00224
# [311]	validation_0-logloss:0.00249	validation_1-logloss:0.00223
# [312]	validation_0-logloss:0.00248	validation_1-logloss:0.00222
# [313]	validation_0-logloss:0.00247	validation_1-logloss:0.00222
# [314]	validation_0-logloss:0.00247	validation_1-logloss:0.00222
# [315]	validation_0-logloss:0.00246	validation_1-logloss:0.00221
# [316]	validation_0-logloss:0.00246	validation_1-logloss:0.00221
# [317]	validation_0-logloss:0.00245	validation_1-logloss:0.00220
# [318]	validation_0-logloss:0.00244	validation_1-logloss:0.00219
# [319]	validation_0-logloss:0.00243	validation_1-logloss:0.00218
# [320]	validation_0-logloss:0.00242	validation_1-logloss:0.00217
# [321]	validation_0-logloss:0.00242	validation_1-logloss:0.00217
# [322]	validation_0-logloss:0.00241	validation_1-logloss:0.00216
# [323]	validation_0-logloss:0.00241	validation_1-logloss:0.00215
# [324]	validation_0-logloss:0.00240	validation_1-logloss:0.00215
# [325]	validation_0-logloss:0.00239	validation_1-logloss:0.00213
# [326]	validation_0-logloss:0.00238	validation_1-logloss:0.00212
# [327]	validation_0-logloss:0.00236	validation_1-logloss:0.00211
# [328]	validation_0-logloss:0.00234	validation_1-logloss:0.00210
# [329]	validation_0-logloss:0.00233	validation_1-logloss:0.00209
# [330]	validation_0-logloss:0.00233	validation_1-logloss:0.00209
# [331]	validation_0-logloss:0.00232	validation_1-logloss:0.00209
# [332]	validation_0-logloss:0.00232	validation_1-logloss:0.00208
# [333]	validation_0-logloss:0.00231	validation_1-logloss:0.00207
# [334]	validation_0-logloss:0.00230	validation_1-logloss:0.00206
# [335]	validation_0-logloss:0.00230	validation_1-logloss:0.00206
# [336]	validation_0-logloss:0.00229	validation_1-logloss:0.00205
# [337]	validation_0-logloss:0.00228	validation_1-logloss:0.00205
# [338]	validation_0-logloss:0.00228	validation_1-logloss:0.00204
# [339]	validation_0-logloss:0.00226	validation_1-logloss:0.00204
# [340]	validation_0-logloss:0.00226	validation_1-logloss:0.00203
# [341]	validation_0-logloss:0.00225	validation_1-logloss:0.00202
# [342]	validation_0-logloss:0.00224	validation_1-logloss:0.00201
# [343]	validation_0-logloss:0.00222	validation_1-logloss:0.00200
# [344]	validation_0-logloss:0.00222	validation_1-logloss:0.00199
# [345]	validation_0-logloss:0.00221	validation_1-logloss:0.00199
# [346]	validation_0-logloss:0.00220	validation_1-logloss:0.00197
# [347]	validation_0-logloss:0.00219	validation_1-logloss:0.00196
# [348]	validation_0-logloss:0.00218	validation_1-logloss:0.00196
# [349]	validation_0-logloss:0.00218	validation_1-logloss:0.00196
# [350]	validation_0-logloss:0.00218	validation_1-logloss:0.00196
# [351]	validation_0-logloss:0.00217	validation_1-logloss:0.00196
# [352]	validation_0-logloss:0.00217	validation_1-logloss:0.00195
# [353]	validation_0-logloss:0.00215	validation_1-logloss:0.00194
# [354]	validation_0-logloss:0.00215	validation_1-logloss:0.00193
# [355]	validation_0-logloss:0.00214	validation_1-logloss:0.00193
# [356]	validation_0-logloss:0.00213	validation_1-logloss:0.00192
# [357]	validation_0-logloss:0.00212	validation_1-logloss:0.00192
# [358]	validation_0-logloss:0.00211	validation_1-logloss:0.00191
# [359]	validation_0-logloss:0.00210	validation_1-logloss:0.00191
# [360]	validation_0-logloss:0.00209	validation_1-logloss:0.00190
# [361]	validation_0-logloss:0.00209	validation_1-logloss:0.00189
# [362]	validation_0-logloss:0.00208	validation_1-logloss:0.00189
# [363]	validation_0-logloss:0.00207	validation_1-logloss:0.00188
# [364]	validation_0-logloss:0.00207	validation_1-logloss:0.00187
# [365]	validation_0-logloss:0.00206	validation_1-logloss:0.00187
# [366]	validation_0-logloss:0.00206	validation_1-logloss:0.00187
# [367]	validation_0-logloss:0.00205	validation_1-logloss:0.00186
# [368]	validation_0-logloss:0.00204	validation_1-logloss:0.00186
# [369]	validation_0-logloss:0.00203	validation_1-logloss:0.00186
# [370]	validation_0-logloss:0.00203	validation_1-logloss:0.00185
# [371]	validation_0-logloss:0.00202	validation_1-logloss:0.00184
# [372]	validation_0-logloss:0.00202	validation_1-logloss:0.00184
# [373]	validation_0-logloss:0.00201	validation_1-logloss:0.00183
# [374]	validation_0-logloss:0.00200	validation_1-logloss:0.00182
# [375]	validation_0-logloss:0.00200	validation_1-logloss:0.00182
# [376]	validation_0-logloss:0.00199	validation_1-logloss:0.00181
# [377]	validation_0-logloss:0.00197	validation_1-logloss:0.00179
# [378]	validation_0-logloss:0.00196	validation_1-logloss:0.00177
# [379]	validation_0-logloss:0.00195	validation_1-logloss:0.00177
# [380]	validation_0-logloss:0.00194	validation_1-logloss:0.00175
# [381]	validation_0-logloss:0.00193	validation_1-logloss:0.00175
# [382]	validation_0-logloss:0.00192	validation_1-logloss:0.00174
# [383]	validation_0-logloss:0.00191	validation_1-logloss:0.00173
# [384]	validation_0-logloss:0.00190	validation_1-logloss:0.00172
# [385]	validation_0-logloss:0.00189	validation_1-logloss:0.00171
# [386]	validation_0-logloss:0.00189	validation_1-logloss:0.00170
# [387]	validation_0-logloss:0.00188	validation_1-logloss:0.00170
# [388]	validation_0-logloss:0.00188	validation_1-logloss:0.00170
# [389]	validation_0-logloss:0.00187	validation_1-logloss:0.00169
# [390]	validation_0-logloss:0.00186	validation_1-logloss:0.00168
# [391]	validation_0-logloss:0.00186	validation_1-logloss:0.00168
# [392]	validation_0-logloss:0.00186	validation_1-logloss:0.00168
# [393]	validation_0-logloss:0.00185	validation_1-logloss:0.00168
# [394]	validation_0-logloss:0.00184	validation_1-logloss:0.00166
# [395]	validation_0-logloss:0.00184	validation_1-logloss:0.00166
# [396]	validation_0-logloss:0.00183	validation_1-logloss:0.00165
# [397]	validation_0-logloss:0.00182	validation_1-logloss:0.00164
# [398]	validation_0-logloss:0.00180	validation_1-logloss:0.00163
# [399]	validation_0-logloss:0.00180	validation_1-logloss:0.00162
# [400]	validation_0-logloss:0.00179	validation_1-logloss:0.00162
# [401]	validation_0-logloss:0.00179	validation_1-logloss:0.00161
# [402]	validation_0-logloss:0.00178	validation_1-logloss:0.00161
# [403]	validation_0-logloss:0.00178	validation_1-logloss:0.00161
# [404]	validation_0-logloss:0.00177	validation_1-logloss:0.00160
# [405]	validation_0-logloss:0.00177	validation_1-logloss:0.00160
# [406]	validation_0-logloss:0.00177	validation_1-logloss:0.00160
# [407]	validation_0-logloss:0.00176	validation_1-logloss:0.00159
# [408]	validation_0-logloss:0.00175	validation_1-logloss:0.00158
# [409]	validation_0-logloss:0.00175	validation_1-logloss:0.00158
# [410]	validation_0-logloss:0.00174	validation_1-logloss:0.00157
# [411]	validation_0-logloss:0.00173	validation_1-logloss:0.00156
# [412]	validation_0-logloss:0.00173	validation_1-logloss:0.00156
# [413]	validation_0-logloss:0.00172	validation_1-logloss:0.00155
# [414]	validation_0-logloss:0.00171	validation_1-logloss:0.00155
# [415]	validation_0-logloss:0.00171	validation_1-logloss:0.00155
# [416]	validation_0-logloss:0.00171	validation_1-logloss:0.00155
# [417]	validation_0-logloss:0.00170	validation_1-logloss:0.00154
# [418]	validation_0-logloss:0.00170	validation_1-logloss:0.00153
# [419]	validation_0-logloss:0.00170	validation_1-logloss:0.00153
# [420]	validation_0-logloss:0.00169	validation_1-logloss:0.00153
# [421]	validation_0-logloss:0.00169	validation_1-logloss:0.00152
# [422]	validation_0-logloss:0.00168	validation_1-logloss:0.00152
# [423]	validation_0-logloss:0.00168	validation_1-logloss:0.00152
# [424]	validation_0-logloss:0.00168	validation_1-logloss:0.00152
# [425]	validation_0-logloss:0.00167	validation_1-logloss:0.00151
# [426]	validation_0-logloss:0.00167	validation_1-logloss:0.00151
# [427]	validation_0-logloss:0.00167	validation_1-logloss:0.00151
# [428]	validation_0-logloss:0.00166	validation_1-logloss:0.00150
# [429]	validation_0-logloss:0.00166	validation_1-logloss:0.00150
# [430]	validation_0-logloss:0.00165	validation_1-logloss:0.00149
# [431]	validation_0-logloss:0.00165	validation_1-logloss:0.00149
# [432]	validation_0-logloss:0.00164	validation_1-logloss:0.00148
# [433]	validation_0-logloss:0.00163	validation_1-logloss:0.00148
# [434]	validation_0-logloss:0.00163	validation_1-logloss:0.00147
# [435]	validation_0-logloss:0.00162	validation_1-logloss:0.00147
# [436]	validation_0-logloss:0.00162	validation_1-logloss:0.00147
# [437]	validation_0-logloss:0.00162	validation_1-logloss:0.00146
# [438]	validation_0-logloss:0.00161	validation_1-logloss:0.00146
# [439]	validation_0-logloss:0.00161	validation_1-logloss:0.00146
# [440]	validation_0-logloss:0.00160	validation_1-logloss:0.00146
# [441]	validation_0-logloss:0.00159	validation_1-logloss:0.00145
# [442]	validation_0-logloss:0.00159	validation_1-logloss:0.00145
# [443]	validation_0-logloss:0.00158	validation_1-logloss:0.00144
# [444]	validation_0-logloss:0.00157	validation_1-logloss:0.00143
# [445]	validation_0-logloss:0.00157	validation_1-logloss:0.00143
# [446]	validation_0-logloss:0.00157	validation_1-logloss:0.00143
# [447]	validation_0-logloss:0.00156	validation_1-logloss:0.00142
# [448]	validation_0-logloss:0.00156	validation_1-logloss:0.00142
# [449]	validation_0-logloss:0.00156	validation_1-logloss:0.00142
# [450]	validation_0-logloss:0.00155	validation_1-logloss:0.00141
# [451]	validation_0-logloss:0.00155	validation_1-logloss:0.00141
# [452]	validation_0-logloss:0.00155	validation_1-logloss:0.00140
# [453]	validation_0-logloss:0.00154	validation_1-logloss:0.00140
# [454]	validation_0-logloss:0.00154	validation_1-logloss:0.00140
# [455]	validation_0-logloss:0.00154	validation_1-logloss:0.00139
# [456]	validation_0-logloss:0.00153	validation_1-logloss:0.00139
# [457]	validation_0-logloss:0.00153	validation_1-logloss:0.00139
# [458]	validation_0-logloss:0.00152	validation_1-logloss:0.00139
# [459]	validation_0-logloss:0.00152	validation_1-logloss:0.00138
# [460]	validation_0-logloss:0.00151	validation_1-logloss:0.00138
# [461]	validation_0-logloss:0.00151	validation_1-logloss:0.00138
# [462]	validation_0-logloss:0.00151	validation_1-logloss:0.00137
# [463]	validation_0-logloss:0.00150	validation_1-logloss:0.00137
# [464]	validation_0-logloss:0.00150	validation_1-logloss:0.00137
# [465]	validation_0-logloss:0.00149	validation_1-logloss:0.00136
# [466]	validation_0-logloss:0.00149	validation_1-logloss:0.00136
# [467]	validation_0-logloss:0.00149	validation_1-logloss:0.00136
# [468]	validation_0-logloss:0.00148	validation_1-logloss:0.00135
# [469]	validation_0-logloss:0.00148	validation_1-logloss:0.00135
# [470]	validation_0-logloss:0.00148	validation_1-logloss:0.00135
# [471]	validation_0-logloss:0.00148	validation_1-logloss:0.00134
# [472]	validation_0-logloss:0.00147	validation_1-logloss:0.00134
# [473]	validation_0-logloss:0.00147	validation_1-logloss:0.00133
# [474]	validation_0-logloss:0.00147	validation_1-logloss:0.00133
# [475]	validation_0-logloss:0.00147	validation_1-logloss:0.00133
# [476]	validation_0-logloss:0.00146	validation_1-logloss:0.00133
# [477]	validation_0-logloss:0.00146	validation_1-logloss:0.00132
# [478]	validation_0-logloss:0.00145	validation_1-logloss:0.00132
# [479]	validation_0-logloss:0.00144	validation_1-logloss:0.00131
# [480]	validation_0-logloss:0.00144	validation_1-logloss:0.00131
# [481]	validation_0-logloss:0.00144	validation_1-logloss:0.00131
# [482]	validation_0-logloss:0.00143	validation_1-logloss:0.00130
# [483]	validation_0-logloss:0.00142	validation_1-logloss:0.00129
# [484]	validation_0-logloss:0.00142	validation_1-logloss:0.00128
# [485]	validation_0-logloss:0.00142	validation_1-logloss:0.00128
# [486]	validation_0-logloss:0.00141	validation_1-logloss:0.00127
# [487]	validation_0-logloss:0.00141	validation_1-logloss:0.00127
# [488]	validation_0-logloss:0.00140	validation_1-logloss:0.00127
# [489]	validation_0-logloss:0.00140	validation_1-logloss:0.00126
# [490]	validation_0-logloss:0.00140	validation_1-logloss:0.00126
# [491]	validation_0-logloss:0.00139	validation_1-logloss:0.00126
# [492]	validation_0-logloss:0.00139	validation_1-logloss:0.00125
# [493]	validation_0-logloss:0.00138	validation_1-logloss:0.00125
# [494]	validation_0-logloss:0.00138	validation_1-logloss:0.00124
# [495]	validation_0-logloss:0.00138	validation_1-logloss:0.00124
# [496]	validation_0-logloss:0.00137	validation_1-logloss:0.00124
# [497]	validation_0-logloss:0.00137	validation_1-logloss:0.00123
# [498]	validation_0-logloss:0.00136	validation_1-logloss:0.00123
# [499]	validation_0-logloss:0.00136	validation_1-logloss:0.00123
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.3, 0.5, 0.7, 1],
#                          'n_estimators': [50, 100, 500]},
#              return_train_score=True)

# %%
result_df = pd.DataFrame(g_xgb.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.3, 'n_estimators': 50}         0.988026
# 1   {'learning_rate': 0.3, 'n_estimators': 100}         0.994224
# 2   {'learning_rate': 0.3, 'n_estimators': 500}         0.995890
# 3    {'learning_rate': 0.5, 'n_estimators': 50}         0.993558
# 4   {'learning_rate': 0.5, 'n_estimators': 100}         0.995557
# 5   {'learning_rate': 0.5, 'n_estimators': 500}         0.995424
# 6    {'learning_rate': 0.7, 'n_estimators': 50}         0.994202
# 7   {'learning_rate': 0.7, 'n_estimators': 100}         0.995179
# 8   {'learning_rate': 0.7, 'n_estimators': 500}         0.995402
# 9      {'learning_rate': 1, 'n_estimators': 50}         0.994113
# 10    {'learning_rate': 1, 'n_estimators': 100}         0.994757
# 11    {'learning_rate': 1, 'n_estimators': 500}         0.994980
#
#     rank_test_score
# 0                12
# 1                 8
# 2                 1
# 3                11
# 4                 2
# 5                 3
# 6                 9
# 7                 5
# 8                 4
# 9                10
# 10                7
# 11                6

# %%
xgb = g_xgb.best_estimator_
xgb_prediction = xgb.predict(X_test)

# %% [markdown]
# #### XGBoost 오차행렬

# %%
get_evaluation(y_test, xgb_prediction, xgb, X_test)
# Out:
# 오차 행렬
# [[4538   18]
#  [  20 5608]]
# 정확도: 0.9963, 정밀도: 0.9968, 재현율: 0.9964, F1: 0.9966, ROC-AUC: 0.9962
# ################################################################################

# %% [markdown]
# ### boosting - LightGBM

# %%
from lightgbm import LGBMClassifier

parameters = {
    'n_estimators': [50, 100, 500],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

X_val_train, X_val_test, y_val_train, y_val_test = \
train_test_split(X_train, y_train, stratify=y_train, test_size=0.2, random_state=124)

evals = [(X_val_train, y_val_train), (X_val_test, y_val_test)]

g_lgbm = GridSearchCV(LGBMClassifier(), param_grid=parameters, cv=5, refit=True, return_train_score=True, n_jobs=-1)
g_lgbm.fit(X_train_over, y_train_over, eval_set=evals)
# Out:
# [LightGBM] [Info] Number of positive: 22508, number of negative: 22508
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001953 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 831
# [LightGBM] [Info] Number of data points in the train set: 45016, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# GridSearchCV(cv=5, estimator=LGBMClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.3, 0.5, 0.7, 1],
#                          'n_estimators': [50, 100, 500]},
#              return_train_score=True)

# %%
result_df = pd.DataFrame(g_lgbm.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.3, 'n_estimators': 50}         0.992469
# 1   {'learning_rate': 0.3, 'n_estimators': 100}         0.995713
# 2   {'learning_rate': 0.3, 'n_estimators': 500}         0.996357
# 3    {'learning_rate': 0.5, 'n_estimators': 50}         0.994180
# 4   {'learning_rate': 0.5, 'n_estimators': 100}         0.995668
# 5   {'learning_rate': 0.5, 'n_estimators': 500}         0.996468
# 6    {'learning_rate': 0.7, 'n_estimators': 50}         0.993869
# 7   {'learning_rate': 0.7, 'n_estimators': 100}         0.979496
# 8   {'learning_rate': 0.7, 'n_estimators': 500}         0.928202
# 9      {'learning_rate': 1, 'n_estimators': 50}         0.979096
# 10    {'learning_rate': 1, 'n_estimators': 100}         0.942933
# 11    {'learning_rate': 1, 'n_estimators': 500}         0.669053
#
#     rank_test_score
# 0                 7
# 1                 3
# 2                 2
# 3                 5
# 4                 4
# 5                 1
# 6                 6
# 7                 8
# 8                11
# 9                 9
# 10               10
# 11               12

# %%
lgbm = g_lgbm.best_estimator_

lgbm_prediction = lgbm.predict(X_test)

# %% [markdown]
# #### LightGBM 오차행렬

# %%
get_evaluation(y_test, lgbm_prediction, lgbm, X_test)
# Out:
# 오차 행렬
# [[4539   17]
#  [  17 5611]]
# 정확도: 0.9967, 정밀도: 0.9970, 재현율: 0.9970, F1: 0.9970, ROC-AUC: 0.9966
# ################################################################################

# %% [markdown]
# ### Voting

# %%
from sklearn.ensemble import VotingClassifier

# 오차 행렬
# [[4544   13]
#  [  18 5609]]
# 정확도: 0.9970, 정밀도: 0.9977, 재현율: 0.9968, F1: 0.9972, ROC-AUC: 0.9970

# vc = VotingClassifier(estimators=[('dtc', dtc),
#                                   ('rfc', rfc),
#                                   ('gbc', gbc),
#                                   ('xgb', xgb),
#                                   ('lgbm', lgbm),
#                                   ('ada', ada),
#                                   ('knn', knn_pipe)], 
#                                   voting='hard', 
#                                   n_jobs=-1)

# 오차 행렬
# [[4546   11]
#  [  14 5613]]
# 정확도: 0.9975, 정밀도: 0.9980, 재현율: 0.9975, F1: 0.9978, ROC-AUC: 0.9975

# 전체적이게 soft가 더 높다
vc = VotingClassifier(estimators=[('dtc', dtc),
                                  ('rfc', rfc),
                                  ('gbc', gbc),
                                  ('xgb', xgb),
                                  ('lgbm', lgbm),
                                  ('ada', ada),
                                  ('knn', knn_pipe)], 
                                  voting='soft', 
                                  n_jobs=-1)

# %% [markdown]
# - 전부 다 0.9 이상이라 그냥 전부 넣고 보팅해보았다

# %%
vc.fit(X_train_over, y_train_over)
# Out:
# VotingClassifier(estimators=[('dtc',
#                               DecisionTreeClassifier(max_depth=24,
#                                                      min_samples_split=50)),
#                              ('rfc',
#                               RandomForestClassifier(max_depth=26,
#                                                      min_samples_split=52)),
#                              ('gbc',
#                               GradientBoostingClassifier(learning_rate=0.5,
#                                                          n_estimators=500)),
#                              ('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsampl...
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=500, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             random_state=None, ...)),
#                              ('lgbm',
#                               LGBMClassifier(learning_rate=0.5,
#                                              n_estimators=500)),
#                              ('ada',
#                               AdaBoostClassifier(learning_rate=1,
#                                                  n_estimators=150)),
#                              ('knn',
#                               Pipeline(steps=[('standard_scaler',
#                                                StandardScaler()),
#                                               ('knn',
#                                                KNeighborsClassifier(n_neighbors=9))]))],
#                  n_jobs=-1, voting='soft')

# %%
vc_prediction = vc.predict(X_test)
get_evaluation(y_test, vc_prediction, vc, X_test)
# Out:
# 오차 행렬
# [[4540   16]
#  [  18 5610]]
# 정확도: 0.9967, 정밀도: 0.9972, 재현율: 0.9968, F1: 0.9970, ROC-AUC: 0.9966
# ################################################################################

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

model_names = ['dtc', 'rfc', 'gbc', 'xgb', 'lgbm', 'ada', 'knn', 'vc']

accuracies = [accuracy_score(y_test, dtc_prediction), accuracy_score(y_test, rfc_prediction), accuracy_score(y_test, gbc_prediction),
              accuracy_score(y_test, xgb_prediction), accuracy_score(y_test, lgbm_prediction), accuracy_score(y_test, ada_prediction),
              accuracy_score(y_test, knn_prediction), accuracy_score(y_test, vc_prediction)]
precisions = [precision_score(y_test, dtc_prediction), precision_score(y_test, rfc_prediction), precision_score(y_test, gbc_prediction),
              precision_score(y_test, xgb_prediction), precision_score(y_test, lgbm_prediction), precision_score(y_test, ada_prediction),
              precision_score(y_test, knn_prediction), precision_score(y_test, vc_prediction)]
recalls = [recall_score(y_test, dtc_prediction), recall_score(y_test, rfc_prediction), recall_score(y_test, gbc_prediction),
           recall_score(y_test, xgb_prediction), recall_score(y_test, lgbm_prediction), recall_score(y_test, ada_prediction),
           recall_score(y_test, knn_prediction), recall_score(y_test, vc_prediction)]
f1_scores = [f1_score(y_test, dtc_prediction), f1_score(y_test, rfc_prediction), f1_score(y_test, gbc_prediction),
             f1_score(y_test, xgb_prediction), f1_score(y_test, lgbm_prediction), f1_score(y_test, ada_prediction),
             f1_score(y_test, knn_prediction), f1_score(y_test, vc_prediction)]

# 성능 지표 출력
print("Model\t\tAccuracy\tPrecision\tRecall\t\tF1 Score")
for i in range(len(model_names)):
    print(f"{model_names[i]}\t\t{accuracies[i]:.4f}\t\t{precisions[i]:.4f}\t\t{recalls[i]:.4f}\t\t{f1_scores[i]:.4f}")

# 데이터프레임 생성
import pandas as pd
data = pd.DataFrame({
    'Model': model_names * 4,
    'Metric': ['Accuracy'] * 8 + ['Precision'] * 8 + ['Recall'] * 8 + ['F1 Score'] * 8,
    'Score': accuracies + precisions + recalls + f1_scores
})

# 시각화
plt.figure(figsize=(10, 6))
sns.barplot(x='Model', y='Score', hue='Metric', data=data, palette='muted')
plt.title('Performance Comparison')
plt.xlabel('Models')
plt.ylabel('Scores')
plt.xticks(rotation=45)
plt.legend(title='Metric')
plt.show()
# Out:
# Model		Accuracy	Precision	Recall		F1 Score
# dtc		0.9773		0.9785		0.9805		0.9795
# rfc		0.9928		0.9945		0.9925		0.9935
# gbc		0.9945		0.9956		0.9945		0.9950
# xgb		0.9963		0.9968		0.9964		0.9966
# lgbm		0.9967		0.9970		0.9970		0.9970
# ada		0.7657		0.8190		0.7395		0.7772
# knn		0.9869		0.9907		0.9856		0.9882
# vc		0.9967		0.9972		0.9968		0.9970

# %% [markdown]
# - 시각화로 비교해보았때 vc를 제외하고 모든 수치가 가장 높은건 lgbm이고 다음은 xgb이다

# %% [markdown]
# #### 정밀도와 재현율 그래프
# > 가장 결과가 좋았던 VC모델 사용

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

def precision_recall_curve_plot(y_test , proba_class1):

    precisions, recalls, thresholds = precision_recall_curve(y_test, proba_class1)
    
    # X축: threshold
    # Y축: 정밀도, 재현율 
    # 정밀도는 점선으로 표시
    plt.figure(figsize=(8,6))
    threshold_boundary = thresholds.shape[0]
    plt.plot(thresholds, precisions[0:threshold_boundary], linestyle='--', label='precision')
    plt.plot(thresholds, recalls[0:threshold_boundary],label='recall')
    
    # X축(threshold)의 Scale을 0 ~ 1 단위로 변경
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1),2))
    
    plt.xlabel('Threshold value'); plt.ylabel('Precision and Recall value')
    plt.legend()
    plt.grid()
    plt.show()
    
precision_recall_curve_plot(y_test, vc.predict_proba(X_test)[:, 1].reshape(-1, 1))

# %% [markdown]
# - 임계치가 0.47정도인 구간에 분포가 많이 된것으로 추정

# %% [markdown]
# #### ROC curve

# %%
from sklearn.metrics import roc_curve

def roc_curve_plot(y_test , proba_class1):
#     임계값에 따른 FPR, TPR 값
    fprs, tprs, thresholds = roc_curve(y_test, proba_class1)

#     ROC Curve를 plot 곡선으로 그림. 
    plt.plot(fprs , tprs, label='ROC')
#     가운데 대각선 직선을 그림. 
#     TPR과 FPR이 동일한 비율로 떨어진다는 것은 모델이 양성과 음성을 구별하지 못한다는 것을 의미한다.
#     다른 분류기를 판단하기 위한 기준선으로 사용되며, 
#     대각선에 가까울 수록 예측에 사용하기 힘든 모델이라는 뜻이다.
    plt.plot([0, 1], [0, 1], 'k--', label='Standard')
    
    # X축(FPR)의 Scale을 0.1 단위로 변경
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1),2))
    plt.xlim(0,1); plt.ylim(0,1)
    plt.xlabel('FPR( 1 - Sensitivity )'); plt.ylabel('TPR( Recall )')
    plt.legend()
    plt.show()
    
roc_curve_plot(y_test, vc.predict_proba(X_test)[:, 1].reshape(-1, 1))

# %% [markdown]
# - ROC-AUC: 0.9966라서 맨위에 붙은 모습

# %%
sns.barplot(x=dtc.feature_importances_, y=features.columns)
plt.show()

# %%
plt.scatter(features.iloc[:, 6], features.iloc[:, -3], c=targets)

# %%
import numpy as np

# Classifier의 Decision Boundary를 시각화 하는 함수
def visualize_boundary(model, X, y):
    fig,ax = plt.subplots()
    
    # 학습 데이타 scatter plot으로 나타내기
    ax.scatter(X.iloc[:, 0], X.iloc[:, 1], c=y, s=25, cmap='rainbow', edgecolor='k',
               clim=(y.min(), y.max()), zorder=3)
    ax.axis('tight')
    ax.axis('off')
    xlim_start , xlim_end = ax.get_xlim()
    ylim_start , ylim_end = ax.get_ylim()
    
    # 호출 파라미터로 들어온 training 데이타로 model 학습 . 
    model.fit(X.values, y)
    # meshgrid 형태인 모든 좌표값으로 예측 수행. 
    xx, yy = np.meshgrid(np.linspace(xlim_start,xlim_end, num=200),np.linspace(ylim_start,ylim_end, num=200))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
    
    # contourf() 를 이용하여 class boundary 를 visualization 수행. 
    n_classes = len(np.unique(y))
    contours = ax.contourf(xx, yy, Z, alpha=0.3,
                           levels=np.arange(n_classes + 1) - 0.5,
                           cmap='rainbow',
                           zorder=1)

# %%
features_6_9 = features.iloc[:, [6, 9]]

# %%
visualize_boundary(dtc, features_6_9, targets)

# %%
visualize_boundary(lgbm, features_6_9, targets)
# Out:
# [LightGBM] [Info] Number of positive: 28136, number of negative: 22781
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000151 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 262
# [LightGBM] [Info] Number of data points in the train set: 50917, number of used features: 2
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.552586 -> initscore=0.211123
# [LightGBM] [Info] Start training from score 0.211123
